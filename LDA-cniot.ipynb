# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Using cached python-docx-0.8.11.tar.gz (5.6 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: lxml>=2.3.2 in c:\users\krg\anaconda3\lib\site-packages (from python-docx) (4.9.1)
# Building wheels for collected packages: python-docx
#   Building wheel for python-docx (setup.py): started
#   Building wheel for python-docx (setup.py): finished with status 'done'
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184519 sha256=a805c89e3d6669399dcbebefdf25bb77fa1669a4eb99d88a4995acd1ec9b2844
#   Stored in directory: c:\users\krg\appdata\local\pip\cache\wheels\65\e1\9b\0c38fe6cfe02a9fe31cb6b4efd90985f17354d7f77872f2def
# Successfully built python-docx
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.11

# %%
import csv
import pandas as pd

data_book = pd.read_csv('train_cniot_book.csv', header=None, names=['data'])
data_book
# Out:
#                                                     data
# 0      The  th century was the era of the great mecha...
# 1        The  th century was the age of the steam engine
# 2      During the  th century  the key technology was...
# 3      Among other developments  we saw the installat...
# 4      As a result of rapid technological progress  t...
# ...                                                  ...
# 21646  The program should take plaintext from the sta...
# 21647  The encryption should be carried out character...
# 21648  For this problem  you are allowed to select an...
# 21649  You may select any output format  as long as i...
# 21650  Make sure to document clearly in your code any...
#
# [21651 rows x 1 columns]

# %%
import gensim
from nltk.stem import WordNetLemmatizer
# nltk.download('omw-1.4')
def ls(text):
    return WordNetLemmatizer().lemmatize(text, pos='v')


# Tokenize and lemmatize
def pp(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS:   # for dbms  and len(token) > 3
            result.append(ls(token))

    return result

# print("\n")
prepro_data = []
for index,line in data_book.iterrows():
    prepro_data.append(pp(line['data']))

if __name__ == "__main__":
    print(prepro_data)
# Out:
# [['th', 'century', 'era', 'great', 'mechanical', 'systems', 'accompany', 'industrial', 'revolution'], ['th', 'century', 'age', 'steam', 'engine'], ['th', 'century', 'key', 'technology', 'information', 'gather', 'process', 'distribution'], ['developments', 'saw', 'installation', 'worldwide', 'telephone', 'network', 'invention', 'radio', 'television', 'birth', 'unprecedented', 'growth', 'industry', 'launch', 'communication', 'satellite', 'course', 'internet'], ['result', 'rapid', 'technological', 'progress', 'areas', 'rapidly', 'converge', 'st', 'century', 'differences', 'collect', 'transport', 'store', 'process', 'information', 'quickly', 'disappear'], ['organizations', 'hundreds', 'offices', 'spread', 'wide', 'geographical', 'area', 'routinely', 'expect', 'able', 'examine', 'current', 'status', 'remote', 'outpost', 'push', 'button'], ['ability', 'gather', 'process', 'distribute', 'information', 'grow', 'demand', 'sophisticate', 'information', 'process', 'grow', 'faster'], ['industry', 'young', 'compare', 'industries'], ['automobile', 'air', 'transportation', 'computers', 'spectacular', 'progress', 'short', 'time'], ['decades', 'existence', 'systems', 'highly', 'centralize', 'usually', 'single', 'large', 'room'], ['infrequently', 'room', 'glass', 'wall', 'visitors', 'gawk', 'great', 'electronic', 'wonder', 'inside'], ['medium', 'size', 'company', 'university', 'introduction'], ['computers', 'large', 'institutions', 'dozen'], ['idea', 'years', 'vastly', 'powerful', 'computers', 'smaller', 'postage', 'stamp', 'mass', 'produce', 'billions', 'pure', 'science', 'fiction'], ['merge', 'computers', 'communications', 'profound', 'influence', 'way', 'systems', 'organize'], ['dominant', 'concept', 'center', 'room', 'large', 'users', 'bring', 'work', 'process', 'totally', 'obsolete', 'data', 'center', 'hold', 'thousands', 'internet', 'servers', 'common'], ['old', 'model', 'single', 'serve', 'organization', 'computational', 'need', 'replace', 'large', 'number', 'separate', 'interconnect', 'computers', 'job'], ['systems', 'call', 'network'], ['design', 'organization', 'network', 'subject', 'book'], ['book', 'use', 'term', 'network', 'mean', 'collection', 'autonomous', 'computers', 'interconnect', 'single', 'technology'], ['computers', 'say', 'interconnect', 'able', 'exchange', 'information'], ['connection', 'need', 'copper', 'wire', 'fiber', 'optics', 'microwave', 'infrared', 'communication', 'satellite'], ['network', 'come', 'size', 'shape', 'form', 'later'], ['usually', 'connect', 'larger', 'network', 'internet', 'know', 'example', 'network', 'network'], ['considerable', 'confusion', 'literature', 'network', 'distribute'], ['key', 'distinction', 'distribute', 'collection', 'independent', 'computers', 'appear', 'users', 'single', 'coherent'], ['usually', 'single', 'model', 'paradigm', 'present', 'users'], ['layer', 'software', 'operate', 'call', 'middleware', 'responsible', 'implement', 'model'], ['know', 'example', 'distribute', 'world', 'wide', 'web'], ['run', 'internet', 'present', 'model', 'look', 'like', 'document', 'web', 'page'], ['network', 'coherence', 'model', 'software', 'absent'], ['users', 'expose', 'actual', 'machine', 'attempt', 'machine', 'look', 'act', 'coherent', 'way'], ['machine', 'different', 'hardware', 'different', 'operate', 'systems', 'fully', 'visible', 'users'], ['user', 'want', 'run', 'program', 'remote', 'machine', 'log', 'machine', 'run'], ['effect', 'distribute', 'software', 'build', 'network'], ['software', 'give', 'high', 'degree', 'cohesiveness', 'transparency'], ['distinction', 'network', 'distribute', 'lie', 'software', 'especially', 'operate', 'hardware'], ['considerable', 'overlap', 'subject'], ['example', 'distribute', 'systems', 'network', 'need', 'file'], ['difference', 'lie', 'invoke', 'movement', 'user'], ['read', 'book'], ['use', 'network', 'book', 'primarily', 'focus', 'network', 'topics', 'important', 'distribute', 'systems'], ['information', 'distribute', 'systems', 'tanenbaum', 'van', 'steen', ...

# %%
import gensim
from gensim import corpora

dict_ = corpora.Dictionary(prepro_data)

print(type(dict_))

# for i,j in dict_.items():
#     print(i, " ", j)
#
#
doc_term_matrix = [dict_.doc2bow(i) for i in prepro_data]
# print(doc_term_matrix)
#
Lda = gensim.models.ldamodel.LdaModel

ldamodel = Lda(doc_term_matrix, num_topics = 100, id2word = dict_, passes=1, random_state=0, eval_every=None)

print(ldamodel.print_topics())

for i in ldamodel.print_topics(num_topics=len(prepro_data), num_words=5):
    print(i)

# count = 0
# for i in ldamodel[doc_term_matrix]:
#     print("doc : ",count,i)
#     count += 1

# lda_model =  gensim.models.LdaMulticore(doc_term_matrix, num_topics = 8, id2word = dict_, passes = 10, workers = 2)
# print(lda_model.print_topic())

topicwise_words = []
topics = ldamodel.show_topics(formatted=False)

for i in range(len(topics)):
    topic_words = dict(topics[i][1])
    word = []
    for ky in topic_words:
        word.append(ky)
    topicwise_words.append(word)

print(topicwise_words)
# Out:
# <class 'gensim.corpora.dictionary.Dictionary'>
# [(70, '0.197*"file" + 0.152*"email" + 0.105*"establish" + 0.103*"line" + 0.078*"transfer" + 0.073*"method" + 0.041*"connection" + 0.031*"send" + 0.020*"lot" + 0.017*"typical"'), (14, '0.322*"fig" + 0.190*"show" + 0.129*"media" + 0.122*"form" + 0.082*"group" + 0.024*"expire" + 0.024*"eventually" + 0.014*"send" + 0.013*"presence" + 0.010*"convenient"'), (73, '0.194*"possible" + 0.150*"encode" + 0.109*"performance" + 0.063*"local" + 0.057*"color" + 0.057*"identifier" + 0.044*"repeat" + 0.039*"cod" + 0.028*"errors" + 0.023*"lookup"'), (77, '0.169*"certificate" + 0.144*"sign" + 0.105*"idea" + 0.078*"years" + 0.071*"distribute" + 0.053*"load" + 0.033*"basic" + 0.027*"active" + 0.022*"previously" + 0.022*"browse"'), (53, '0.160*"node" + 0.128*"image" + 0.103*"version" + 0.095*"communication" + 0.050*"major" + 0.047*"specific" + 0.045*"future" + 0.043*"completely" + 0.039*"grow" + 0.035*"subject"'), (19, '0.193*"video" + 0.184*"set" + 0.133*"audio" + 0.105*"add" + 0.081*"space" + 0.061*"hold" + 0.029*"methods" + 0.028*"meet" + 0.028*"outside" + 0.022*"watch"'), (82, '0.236*"bandwidth" + 0.179*"share" + 0.171*"instead" + 0.033*"use" + 0.030*"network" + 0.030*"fraction" + 0.029*"supply" + 0.022*"accord" + 0.019*"valuable" + 0.018*"attach"'), (7, '0.163*"look" + 0.144*"way" + 0.130*"include" + 0.118*"like" + 0.086*"connections" + 0.050*"rule" + 0.048*"old" + 0.025*"bad" + 0.023*"trouble" + 0.016*"link"'), (60, '0.194*"packets" + 0.169*"field" + 0.090*"destination" + 0.090*"generate" + 0.074*"document" + 0.056*"book" + 0.037*"update" + 0.035*"database" + 0.030*"choice" + 0.028*"complex"'), (66, '0.198*"handle" + 0.112*"easy" + 0.094*"ethernet" + 0.093*"bank" + 0.093*"far" + 0.077*"manage" + 0.070*"continue" + 0.040*"learn" + 0.027*"commerce" + 0.020*"impossible"'), (24, '0.429*"internet" + 0.125*"clients" + 0.040*"network" + 0.037*"area" + 0.035*"architecture" + 0.024*"connect" + 0.017*"evolve" + 0.016*"highest" + 0.016*"substantial" + 0.015*"core"'), (75, '0.193*"people" + 0.133*"standard" + 0.101*"routers" + 0.076*"government" + 0.057*"communicate" + 0.054*"language" + 0.043*"remain" + 0.036*"identity" + 0.027*"standards" + 0.026*"wish"'), (81, '0.243*"receive" + 0.240*"change" + 0.096*"signal" + 0.088*"avoid" + 0.055*"intend" + 0.040*"wireless" + 0.029*"difficulty" + 0.023*"upper" + 0.017*"time" + 0.015*"receiver"'), (6, '0.233*"protocol" + 0.146*"program" + 0.130*"type" + 0.123*"packet" + 0.059*"define" + 0.056*"function" + 0.037*"perform" + 0.030*"send" + 0.023*"derive" + 0.015*"stage"'), (98, '0.445*"bob" + 0.126*"encryption" + 0.095*"issue" + 0.081*"require" + 0.025*"use" + 0.020*"necessary" + 0.017*"finish" + 0.017*"connectivity" + 0.015*"military" + 0.014*"fit"'), (45, '0.234*"connection" + 0.214*"service" + 0.153*"follow" + 0.118*"text" + 0.031*"contrast" + 0.030*"offer" + 0.029*"execute" + 0.024*"orient" + 0.019*"circle" + 0.014*"charge"'), (16, '0.244*"design" + 0.105*"character" + 0.079*"procedure" + 0.073*"expect" + 0.071*"current" + 0.042*"achieve" + 0.031*"button" + 0.029*"direct" + 0.022*"status" + 0.021*"entirely"'), (29, '0.222*"peer" + 0.108*"display" + 0.086*"contact" + 0.077*"exchange" + 0.045*"concern" + 0.038*"job" + 0.034*"move" + 0.028*"library" + 0.028*"monitor" + 0.022*"despite"'), (9, '0.320*"public" + 0.087*"real" + 0.087*"reduce" + 0.076*"download" + 0.055*"consist" + 0.047*"distribution" + 0.043*"time" + 0.034*"network" + 0.027*"ap" + 0.023*"movies"'), (91, '0.335*"consider" + 0.207*"better" + 0.098*"faster" + 0.072*"fiber" + 0.041*"stand" + 0.021*"long" + 0.014*"board" + 0.011*"wireless" + 0.011*"perfect" + 0.010*"deployment"')]
# (0, '0.242*"mean" + 0.216*"reason" + 0.081*"demand" + 0.065*"frequency" + 0.052*"upload"')
# (1, '0.424*"new" + 0.070*"purpose" + 0.067*"part" + 0.050*"maintain" + 0.045*"construct"')
# (2, '0.445*"server" + 0.076*"good" + 0.074*"small" + 0.054*"think" + 0.045*"play"')
# (3, '0.209*"record" + 0.123*"problems" + 0.089*"help" + 0.088*"apply" + 0.080*"view"')
# (4, '0.202*"lose" + 0.128*"transmission" + 0.086*"appear" + 0.078*"queue" + 0.058*"transform"')
# (5, '0.300*"authentication" + 0.151*"place" + 0.124*"home" + 0.052*"mobile" + 0.041*"location"')
# (6, '0.233*"protocol" + 0.146*"program" + 0.130*"type" + 0.123*"packet" + 0.059*"define"')
# (7, '0.163*"look" + 0.144*"way" + 0.130*"include" + 0.118*"like" + 0.086*"connections"')
# (8, '0.173*"happen" + 0.148*"see" + 0.107*"select" + 0.092*"best" + 0.068*"examples"')
# (9, '0.320*"public" + 0.087*"real" + 0.087*"reduce" + 0.076*"download" + 0.055*"consist"')
# (10, '0.182*"algorithm" + 0.154*"size" + 0.087*"rfc" + 0.076*"fetch" + 0.063*"parameters"')
# (11, '0.168*"give" + 0.129*"servers" + 0.122*"tell" + 0.087*"carry" + 0.080*"word"')
# (12, '0.311*"frame" + 0.229*"send" + 0.055*"successor" + 0.043*"versions" + 0.032*"style"')
# (13, '0.240*"allow" + 0.194*"base" + 0.060*"use" + 0.055*"authenticate" + 0.055*"additional"')
# (14, '0.322*"fig" + 0.190*"show" + 0.129*"media" + 0.122*"form" + 0.082*"group"')
# (15, '0.414*"address" + 0.122*"sit" + 0.101*"private" + 0.050*"range" + 0.040*"represent"')
# (16, '0.244*"design" + 0.105*"character" + 0.079*"procedure" + 0.073*"expect" + 0.071*"current"')
# (17, '0.196*"site" + 0.165*"return" + 0.074*"modify" + 0.065*"acknowledgement" + 0.062*"acknowledge"')
# (18, '0.459*"web" + 0.080*"domain" + 0.056*"talk" + 0.048*"simply" + 0.035*"person"')
# (19, '0.193*"video" + 0.184*"set" + 0.133*"audio" + 0.105*"add" + 0.081*"space"')
# (20, '0.173*"different" + 0.136*"problem" + 0.117*"control" + 0.104*"multiple" + 0.077*"later"')
# (21, '0.134*"simple" + 0.120*"flow" + 0.108*"kb" + 0.103*"main" + 0.078*"software"')
# (22, '0.214*"break" + 0.189*"input" + 0.128*"transmit" + 0.067*"error" + 0.049*"decide"')
# (23, '0.173*"applications" + 0.150*"read" + 0.096*"channel" + 0.093*"class" + 0.078*"yes"')
# (24, '0.429*"internet" + 0.125*"clients" + 0.040*"network" + 0.037*"area" + 0.035*"architecture"')
# (25, '0.201*"window" + 0.184*"suppose" + 0.174*"reply" + 0.071*"kinds" + 0.054*"send"')
# (26, '0.134*"pass" + 0.097*"card" + 0.074*"computers" + 0.074*"illustrate" + 0.067*"interface"')
# (27, '0.222*"sequence" + 0.167*"take" + 0.120*"exist" + 0.061*"technique" + 0.038*"aware"')
# (28, '0.229*"ure" + 0.158*"world" + 0.064*"burst" + 0.056*"average" + 0.051*"computation"')
# (29, '0.222*"peer" + 0.108*"display" + 0.086*"contact" + 0.077*"exchange" + 0.045*"concern"')
# (30, '0.184*"kind" + 0.161*"filter" + 0.126*"property" + 0.078*"advance" + 0.069*"option"')
# (31, '0.223*"need" + 0.202*"traffic" + 0.164*"large" + 0.066*"accept" + 0.034*"track"')
# (32, '0.118*"increase" + 0.113*"course" + 0.098*"indicate" + 0.094*"cause" + 0.091*"delivery"')
# (33, '0.616*"example" + 0.072*"structure" + 0.036*"rest" + 0.034*"count" + 0.025*"notice"')
# (34, '0.209*"session" + 0.148*"html" + 0.117*"http" + 0.103*"table" + 0.049*"factor"')
# (35, '0.268*"block" + 0.235*"bits" + 0.128*"store" + 0.088*"random" + 0.033*"memory"')
# (36, '0.182*"browser" + 0.178*"want" + 0.173*"users" + 0.097*"level" + 0.045*"tion"')
# (37, '0.362*"case" + 0.183*"have" + 0.111*"respond" + 0.059*"account" + 0.036*"divide"')
# (38, '0.234*"order" + 0.167*"name" + 0.116*"complete" + 0.078*"limit" + 0.067*"higher"')
# (39, '0.173*"mail" + 0.161*"state" + 0.089*"integrity" + 0.084*"slow" + 0.068*"prevent"')
# (40, '0.247*"host" + 0.162*"run" + 0.137*"source" + 0.065*"pick" + 0.061*"tag"')
# (41, '0.168*"buffer" + 0.126*"path" + 0.119*"letter" + 0.069*"depend" + 0.053*"advantage"')
# (42, '0.275*"client" + 0.127*"go" + 0.101*"et" + 0.097*"al" + 0.081*"correct"')
# (43, '0.206*"result" + 0.127*"digital" + 0.108*"say" + 0.077*"year" + 0.067*"industry"')
# (44, '0.279*"stream" + 0.198*"step" + 0.182*"byte" + 0.145*"bytes" + 0.040*"obtain"')
# (45, '0.234*"connection" + 0.214*"service" + 0.153*"follow" + 0.118*"text" + 0.031*"contrast"')
# (46, '0.293*"work" + 0.122*"try" + 0.084*"fact" + 0.074*"popular" + 0.061*"note"')
# (47, '0.204*"point" + 0.102*"isp" + 0.084*"privacy" + 0.074*"customer" + 0.072*"sure"')
# (48, '0.102*"station" + 0.089*"replace" + 0.087*"begin" + 0.078*"probably" + 0.075*"lead"')
# (49, '0.183*"wait" + 0.166*"incoming" + 0.061*"probability" + 0.047*"acquire" + 0.043*"terminate"')
# (50, '0.181*"single" + 0.119*"rate" + 0.091*"original" + 0.085*"actually" + 0.058*"similar"')
# (51, '0.131*"chain" + 0.093*"movie" + 0.067*"owner" + 0.062*"embed" + 0.056*"independently"')
# (52, '0.428*"data" + 0.103*"leave" + 0.073*"link" + 0.059*"mbps" + 0.052*"layer"')
# (53, '0.160*"node" + 0.128*"image" + 0.103*"version" + 0.095*"communication" + 0.050*"major"')
# (54, '0.243*"ip" + 0.167*"tcp" + 0.117*"protocols" + 0.112*"dns" + 0.035*"application"')
# (55, '0.191*"sender" + 0.154*"format" + 0.145*"receiver" + 0.141*"scheme" + 0.097*"easily"')
# (56, '0.175*"process" + 0.166*"provide" + 0.144*"machine" + 0.096*"cryptography" + 0.057*"network"')
# (57, '0.158*"sample" + 0.146*"short" + 0.128*"build" + 0.067*"numerous" + 0.059*"center"')
# (58, '0.335*"time" + 0.145*"come" + 0.081*"common" + 0.065*"round" + 0.056*"practice"')
# (59, '0.331*"figure" + 0.136*"ask" + 0.131*"router" + 0.076*"question" + 0.047*"test"')
# (60, '0.194*"packets" + 0.169*"field" + 0.090*"destination" + 0.090*"generate" + 0.074*"document"')
# (61, '0.183*"query" + 0.115*"map" + 0.064*"discard" + 0.047*"department" + 0.042*"saw"')
# (62, '0.312*"code" + 0.205*"output" + 0.087*"player" + 0.084*"effect" + 0.060*"half"')
# (63, '0.320*"number" + 0.218*"request" + 0.065*"send" + 0.058*"nod" + 0.034*"party"')
# (64, '0.190*"length" + 0.118*"available" + 0.113*"specify" + 0.080*"situation" + 0.063*"bluetooth"')
# (65, '0.140*"company" + 0.109*"box" + 0.083*"body" + 0.076*"create" + 0.066*"voice"')
# (66, '0.198*"handle" + 0.112*"easy" + 0.094*"ethernet" + 0.093*"bank" + 0.093*"far"')
# (67, '0.178*"usually" + 0.115*"free" + 0.079*"implementation" + 0.053*"implementations" + 0.047*"worse"')
# (68, '0.319*"ond" + 0.135*"headers" + 0.071*"business" + 0.068*"directly" + 0.048*"imagine"')
# (69, '0.377*"user" + 0.133*"port" + 0.045*"relate" + 0.042*"drop" + 0.033*"clear"')
# (70, '0.197*"file" + 0.152*"email" + 0.105*"establish" + 0.103*"line" + 0.078*"transfer"')
# (71, '0.119*"model" + 0.115*"matter" + 0.100*"feature" + 0.090*"valid" + 0.070*"difference"')
# (72, '0.180*"list" + 0.159*"algorithms" + 0.084*"discuss" + 0.080*"able" + 0.047*"agree"')
# (73, '0.194*"possible" + 0.150*"encode" + 0.109*"performance" + 0.063*"local" + 0.057*"color"')
# (74, '0.118*"solution" + 0.062*"trip" + 0.061*"organization" + 0.060*"triple" + 0.051*"restrict"')
# (75, '0.193*"people" + 0.133*"standard" + 0.101*"routers" + 0.076*"government" + 0.057*"communicate"')
# (76, '0.271*"delay" + 0.101*"firewalls" + 0.063*"jitter" + 0.062*"measure" + 0.047*"transit"')
# (77, '0.169*"certificate" + 0.144*"sign" + 0.105*"idea" + 0.078*"years" + 0.071*"distribute"')
# (78, '0.160*"congestion" + 0.142*"value" + 0.119*"response" + 0.099*"rout" + 0.058*"live"')
# (79, '0.255*"know" + 0.244*"content" + 0.113*"segment" + 0.112*"get" + 0.082*"mode"')
# (80, '0.149*"term" + 0.095*"legal" + 0.076*"desire" + 0.069*"highly" + 0.061*"explicit"')
# (81, '0.243*"receive" + 0.240*"change" + 0.096*"signal" + 0.088*"avoid" + 0.055*"intend"')
# (82, '0.236*"bandwidth" + 0.179*"share" + 0.171*"instead" + 0.033*"use" + 0.030*"network"')
# (83, '0.184*"make" + 0.110*"turn" + 0.094*"operate" + 0.059*"cost" + 0.042*"money"')
# (84, '0.168*"long" + 0.117*"support" + 0.078*"forward" + 0.060*"head" + 0.049*"inside"')
# (85, '0.121*"arrive" + 0.119*"finally" + 0.061*"packet" + 0.059*"dynamic" + 0.050*"paths"')
# (86, '0.198*"release" + 0.186*"power" + 0.066*"essential" + 0.058*"series" + 0.045*"rfcs"')
# (87, '0.401*"message" + 0.213*"page" + 0.083*"send" + 0.048*"write" + 0.042*"search"')
# (88, '0.088*"widely" + 0.072*"match" + 0.059*"virtual" + 0.059*"route" + 0.053*"previous"')
# (89, '0.531*"key" + 0.226*"urity" + 0.039*"systems" + 0.038*"network" + 0.031*"useful"')
# (90, '0.189*"encrypt" + 0.163*"contain" + 0.156*"information" + 0.061*"answer" + 0.045*"cryptographic"')
# (91, '0.335*"consider" + 0.207*"better" + 0.098*"faster" + 0.072*"fiber" + 0.041*"stand"')
# (92, '0.171*"end" + 0.137*"let" + 0.116*"check" + 0.092*"choose" + 0.076*"right"')
# (93, '0.129*"present" + 0.113*"general" + 0.090*"likely" + 0.081*"reach" + 0.051*"interest"')
# (94, '0.684*"bite" + 0.046*"lan" + 0.034*"draw" + 0.025*"use" + 0.016*"situations"')
# (95, '0.109*"quality" + 0.100*"speed" + 0.080*"register" + 0.074*"radio" + 0.071*"improve"')
# (96, '0.304*"attack" + 0.105*"loss" + 0.057*"event" + 0.043*"crash" + 0.038*"true"')
# (97, '0.242*"layer" + 0.208*"header" + 0.155*"transport" + 0.089*"network" + 0.071*"application"')
# (98, '0.445*"bob" + 0.126*"encryption" + 0.095*"issue" + 0.081*"require" + 0.025*"use"')
# (99, '0.208*"start" + 0.146*"compute" + 0.086*"compression" + 0.071*"produce" + 0.048*"understand"')
# [['order', 'name', 'complete', 'limit', 'higher', 'discussion', 'rat', 'inspect', 'package', 'principles'], ['sample', 'short', 'build', 'numerous', 'center', 'elements', 'interval', 'disconnect', 'bring', 'political'], ['stream', 'step', 'byte', 'bytes', 'obtain', 'proposal', 'legacy', 'follow', 'segment', 'arrive'], ['certificate', 'sign', 'idea', 'years', 'distribute', 'load', 'basic', 'active', 'previously', 'browse'], ['protocol', 'program', 'type', 'packet', 'define', 'function', 'perform', 'send', 'derive', 'stage'], ['browser', 'want', 'users', 'level', 'tion', 'use', 'send', 'cause', 'gateway', 'sessions'], ['people', 'standard', 'routers', 'government', 'communicate', 'language', 'remain', 'identity', 'standards', 'wish'], ['block', 'bits', 'store', 'random', 'memory', 'find', 'goal', 'chance', 'damage', 'electrical'], ['start', 'compute', 'compression', 'produce', 'understand', 'mpeg', 'mark', 'claim', 'stop', 'redundancy'], ['long', 'support', 'forward', 'head', 'inside', 'cover', 'action', 'entity', 'packet', 'operation']]

# %%
for word in dict_.items():
    print(word)
# Out:
# (0, 'accompany')
# (1, 'century')
# (2, 'era')
# (3, 'great')
# (4, 'industrial')
# (5, 'mechanical')
# (6, 'revolution')
# (7, 'systems')
# (8, 'th')
# (9, 'age')
# (10, 'engine')
# (11, 'steam')
# (12, 'distribution')
# (13, 'gather')
# (14, 'information')
# (15, 'key')
# (16, 'process')
# (17, 'technology')
# (18, 'birth')
# (19, 'communication')
# (20, 'course')
# (21, 'developments')
# (22, 'growth')
# (23, 'industry')
# (24, 'installation')
# (25, 'internet')
# (26, 'invention')
# (27, 'launch')
# (28, 'network')
# (29, 'radio')
# (30, 'satellite')
# (31, 'saw')
# (32, 'telephone')
# (33, 'television')
# (34, 'unprecedented')
# (35, 'worldwide')
# (36, 'areas')
# (37, 'collect')
# (38, 'converge')
# (39, 'differences')
# (40, 'disappear')
# (41, 'progress')
# (42, 'quickly')
# (43, 'rapid')
# (44, 'rapidly')
# (45, 'result')
# (46, 'st')
# (47, 'store')
# (48, 'technological')
# (49, 'transport')
# (50, 'able')
# (51, 'area')
# (52, 'button')
# (53, 'current')
# (54, 'examine')
# (55, 'expect')
# (56, 'geographical')
# (57, 'hundreds')
# (58, 'offices')
# (59, 'organizations')
# (60, 'outpost')
# (61, 'push')
# (62, 'remote')
# (63, 'routinely')
# (64, 'spread')
# (65, 'status')
# (66, 'wide')
# (67, 'ability')
# (68, 'demand')
# (69, 'distribute')
# (70, 'faster')
# (71, 'grow')
# (72, 'sophisticate')
# (73, 'compare')
# (74, 'industries')
# (75, 'young')
# (76, 'air')
# (77, 'automobile')
# (78, 'computers')
# (79, 'short')
# (80, 'spectacular')
# (81, 'time')
# (82, 'transportation')
# (83, 'centralize')
# (84, 'decades')
# (85, 'existence')
# (86, 'highly')
# (87, 'large')
# (88, 'room')
# (89, 'single')
# (90, 'usually')
# (91, 'electronic')
# (92, 'gawk')
# (93, 'glass')
# (94, 'infrequently')
# (95, 'inside')
# (96, 'visitors')
# (97, 'wall')
# (98, 'wonder')
# (99, 'company')
# (100, 'introduction')
# (101, 'medium')
# (102, 'size')
# (103, 'university')
# (104, 'dozen')
# (105, 'institutions')
# (106, 'billions')
# (107, 'fiction')
# (108, 'idea')
# (109, 'mass')
# (110, 'postage')
# (111, 'powerful')
# (112, 'produce')
# (113, 'pure')
# (114, 'science')
# (115, 'smaller')
# (116, 'stamp')
# (117, 'vastly')
# (118, 'years')
# (119, 'communications')
# (120, 'influence')
# (121, 'merge')
# (122, 'organize')
# (123, 'profound')
# (124, 'way')
# (125, 'bring')
# (126, 'center')
# (127, 'common')
# (128, 'concept')
# (129, 'data')
# (130, 'dominant')
# (131, 'hold')
# (132, 'obsolete')
# (133, 'servers')
# (134, 'thousands')
# (135, 'totally')
# (136, 'users')
# (137, 'work')
# (138, 'computational')
# (139, 'interconnect')
# (140, 'job')
# (141, 'model')
# (142, 'need')
# (143, 'number')
# (144, 'old')
# (145, 'organization')
# (146, 'replace')
# (147, 'separate')
# (148, 'serve')
# (149, 'call')
# (150, 'book')
# (151, 'design')
# (152, 'subject')
# (153, 'autonomous')
# (154, 'collection')
# (155, 'mean')
# (156, 'term')
# (157, 'use')
# (158, 'exchange')
# (159, 'say')
# (160, 'connection')
# (161, 'copper')
# (162, 'fiber')
# (163, 'infrared')
# (164, 'microwave')
# (165, 'optics')
# (166, 'wire')
# (167, 'come')
# (168, 'form')
# (169, 'later')
# (170, 'shape')
# (171, 'connect')
# (172, 'example')
# (173, 'know')
# (174, 'larger')
# (175, 'confusion')
# (176, 'considerable')
# (177, 'literature')
# (178, 'appear')
# (179, 'coherent')
# (180, 'distinction')
# (181, 'independent')
# (182, 'paradigm')
# (183, 'present')
# (184, 'implement')
# (185, 'layer')
# (186, 'middleware')
# (187, 'operate')
# (188, 'responsible')
# (189, 'software')
# (190, 'web')
# (191, 'world')
# (192, 'document')
# (193, 'like')
# (194, 'look')
# (195, 'page')
# (196, 'run')
# (197, 'absent')
# (198, 'coherence')
# (199, 'act')
# (200, 'actual')
# (201, 'attempt')
# (202, 'expose')
# (203, 'machine')
# (204, 'different')
# (205, 'fully')
# (206, 'hardware')
# (207, 'visible')
# (208, 'log')
# (209, 'program')
# (210, 'user')
# (211, 'want')
# (212, 'build')
# (213, 'effect')
# (214, 'cohesiveness')
# (215, 'degree')
# (216, 'give')
# (217, 'high')
# (218, 'transparency')
# (219, 'especially')
# (220, 'lie')
# (221, 'overlap')
# (222, 'file')
# (223, 'difference')
# (224, 'invoke')
# (225, 'movement')
# (226, 'read')
# (227, 'focus')
# (228, 'important')
# (229, 'primarily')
# (230, 'topics')
# (231, 'devote')
# (232, 'interest')
# (233, 'issue')
# (234, 'people')
# (235, 'point')
# (236, 'start')
# (237, 'steen')
# (238, 'tanenbaum')
# (239, 'technical')
# (240, 'van')
# (241, 'worth')
# (242, 'finish')
# (243, 'home')
# (244, 'mobile')
# (245, 'recent')
# (246, 'social')
# (247, 'traditional')
# (248, 'applications')
# (249, 'business')
# (250, 'substantial')
# (251, 'brochures')
# (252, 'payroll')
# (253, 'products')
# (254, 'worker')
# (255, 'write')
# (256, 'decide')
# (257, 'initially')
# (258, 'isolation')
# (259, 'management')
# (260, 'general')
# (261, 'resource')
# (262, 'share')
# (263, 'slightly')
# (264, 'available')
# (265, 'equipment')
# (266, 'goal')
# (267, 'location')
# (268, 'physical')
# (269, 'regard')
# (270, 'group')
# (271, 'have')
# (272, 'obvious')
# (273, 'office')
# (274, 'printer')
# (275, 'widespread')
# (276, 'workers')
# (277, 'cheaper')
# (278, 'easier')
# (279, 'individual')
# (280, 'individuals')
# (281, 'maintain')
# (282, 'printers')
# (283, 'private')
# (284, 'volume')
# (285, 'backup')
# (286, 'probably')
# (287, 'resources')
# (288, 'tape')
# (289, 'computerize')
# (290, 'dependent')
# (291, 'small')
# (292, 'vitally')
# (293, 'customer')
# (294, 'financial')
# (295, 'inventory')
# (296, 'online')
# (297, 'product')
# (298, 'record')
# (299, 'statements')
# (300, 'tax')
# (301, 'bank')
# (302, 'go')
# (303, 'minutes')
# (304, 'suddenly')
# (305, 'assembly')
# (306, 'control')
# (307, 'line')
# (308, 'manufacture')
# (309, 'modern')
# (310, 'onds')
# (311, 'plant')
# (312, 'access')
# (313, 'agency')
# (314, 'allow')
# (315, 'employees')
# (316, 'firm')
# (317, 'instantly')
# (318, 'law')
# (319, 'person')
# (320, 'relevant')
# (321, 'travel')
# (322, 'countries')
# (323, 'dozens')
# (324, 'likely')
# (325, 'ones')
# (326, 'scatter')
# (327, 'new')
# (328, 'sales')
# (329, 'york')
# (330, 'database')
# (331, 'singapore')
# (332, 'extend')
# (333, 'join')
# (334, 'sit')
# (335, 'virtual')
# (336, 'vpns')
# (337, 'away')
# (338, 'fact')
# (339, 'happen')
# (340, 'local')
# (341, 'mere')
# (342, 'prevent')
# (343, 'word')
# (344, 'end')
# (345, 'geography')
# (346, 'summarize')
# (347, 'tyranny')
# (348, 'consist')
# (349, 'databases')
# (350, 'imagine')
# (351, 'remotely')
# (352, 'simplest')
# (353, 'administrator')
# (354, 'centrally')
# (355, 'house')
# (356, 'clients')
# (357, 'construct')
# (358, 'contrast')
# (359, 'desks')
# (360, 'include')
# (361, 'simpler')
# (362, 'spreadsheets')
# (363, 'clear')
# (364, 'client')
# (365, 'context')
# (366, 'human')
# (367, 'refer')
# (368, 'fig')
# (369, 'illustrate')
# (370, 'server')
# (371, 'note')
# (372, 'oval')
# (373, 'show')
# (374, 'simple')
# (375, 'abstract')
# (376, 'sense')
# (377, 'provide')
# (378, 'require')
# (379, 'figure')
# (380, 'arrangement')
# (381, 'basis')
# (382, 'usage')
# (383, 'widely')
# (384, 'application')
# (385, 'base')
# (386, 'generate')
# (387, 'popular')
# (388, 'realization')
# (389, 'request')
# (390, 'response')
# (391, 'update')
# (392, 'apart')
# (393, 'applicable')
# (394, 'belong')
# (395, 'far')
# (396, 'employ')
# (397, 'personal')
# (398, 'condition')
# (399, 'handle')
# (400, 'simultaneously')
# (401, 'involve')
# (402, 'message')
# (403, 'send')
# (404, 'take')
# (405, 'reply')
# (406, 'wait')
# (407, 'get')
# (408, 'perform')
# (409, 'ond')
# (410, 'set')
# (411, 'daily')
# (412, 'deal')
# (413, 'email')
# (414, 'generally')
# (415, 'mail')
# (416, 'virtually')
# (417, 'boss')
# (418, 'content')
# (419, 'cooler')
# (420, 'discover')
# (421, 'free')
# (422, 'gripe')
# (423, 'meaningless')
# (424, 'subordinate')
# (425, 'water')
# (426, 'carry')
# (427, 'instead')
# (428, 'phone')
# (429, 'ip')
# (430, 'telephony')
# (431, 'voice')
# (432, 'voip')
# (433, 'employee')
# (434, 'enable')
# (435, 'microphone')
# (436, 'speaker')
# (437, 'bill')
# (438, 'save')
# (439, 'wonderful')
# (440, 'possible')
# (441, 'richer')
# (442, 'add')
# (443, 'audio')
# (444, 'distant')
# (445, 'hear')
# (446, 'locations')
# (447, 'meet')
# (448, 'video')
# (449, 'cost')
# (450, 'eliminate')
# (451, 'previously')
# (452, 'technique')
# (453, 'tool')
# (454, 'desktop')
# (455, 'graphical')
# (456, 'interact')
# (457, 'let')
# (458, 'screen')
# (459, 'blackboard')
# (460, 'easy')
# (461, 'make')
# (462, 'report')
# (463, 'change')
# (464, 'days')
# (465, 'immediately')
# (466, 'letter')
# (467, 'cooperation')
# (468, 'fling')
# (469, 'impossible')
# (470, 'speedup')
# (471, 'ambitious')
# (472, 'coordination')
# (473, 'telemedicine')
# (474, 'monitor')
# (475, 'patient')
# (476, 'race')
# (477, 'whichever')
# (478, 'win')
# (479, 'customers')
# (480, 'electronically')
# (481, 'suppliers')
# (482, 'commerce')
# (483, 'airlines')
# (484, 'bookstores')
# (485, 'convenience')
# (486, 'retailers')
# (487, 'shop')
# (488, 'catalog')
# (489, 'consequently')
# (490, 'goods')
# (491, 'order')
# (492, 'service')
# (493, 'aircraft')
# (494, 'assemble')
# (495, 'buy')
# (496, 'manufacturers')
# (497, 'part')
# (498, 'subsystems')
# (499, 'variety')
# (500, 'place')
# (501, 'efficiency')
# (502, 'enhance')
# (503, 'reduce')
# (504, 'corporation')
# (505, 'digital')
# (506, 'ibm')
# (507, 'ken')
# (508, 'olsen')
# (509, 'president')
# (510, 'vendor')
# (511, 'ask')
# (512, 'big')
# (513, 'market')
# (514, 'reason')
# (515, 'exist')
# (516, 'history')
# (517, 'longer')
# (518, 'game')
# (519, 'biggest')
# (520, 'recently')
# (521, 'box')
# (522, 'broadly')
# (523, 'clock')
# (524, 'console')
# (525, 'consumer')
# (526, 'create')
# (527, 'devices')
# (528, 'embed')
# (529, 'entertainment')
# (530, 'listen')
# (531, 'music')
# (532, 'photos')
# (533, 'videos')
# (534, 'wireless')
# (535, 'connectivity')
# (536, 'communicate')
# (537, 'benefit')
# (538, 'main')
# (539, 'outside')
# (540, 'bob')
# (541, 'connections')
# (542, 'ethernet')
# (543, 'gilder')
# (544, 'hypothesize')
# (545, 'inventor')
# (546, 'metcalfe')
# (547, 'proportional')
# (548, 'roughly')
# (549, 'square')
# (550, 'value')
# (551, 'hypothesis')
# (552, 'explain')
# (553, 'help')
# (554, 'popularity')
# (555, 'tremendous')
# (556, 'fun')
# (557, 'surf')
# (558, 'arts')
# (559, 'cook')
# (560, 'government')
# (561, 'health')
# (562, 'hobbies')
# (563, 'recreation')
# (564, 'sport')
# (565, 'better')
# (566, 'leave')
# (567, 'mention')
# (568, 'plus')
# (569, 'unmentioned')
# (570, 'ways')
# (571, 'newspapers')
# (572, 'personalize')
# (573, 'celebrities')
# (574, 'corrupt')
# (575, 'epidemics')
# (576, 'fire')
# (577, 'football')
# (578, 'newspaper')
# (579, 'politicians')
# (580, 'scandals')
# (581, 'tell')
# (582, 'thank')
# (583, 'article')
# (584, 'download')
# (585, 'select')
# (586, 'sleep')
# (587, 'cause')
# (588, 'chain')
# (589, 'continue')
# (590, 'link')
# (591, 'massive')
# (592, 'paperboys')
# (593, 'production')
# (594, 'trend')
# (595, 'unemployment')
# (596, 'weakest')
# (597, 'year')
# (598, 'entirely')
# (599, 'money')
# (600, 'journals')
# (601, 'library')
# (602, 'magazines')
# (603, 'scientific')
# (604, 'step')
# (605, 'acm')
# (606, 'conference')
# (607, 'ieee')
# (608, 'proceed')
# (609, 'professional')
# (610, 'society')
# (611, 'libraries')
# (612, 'print')
# (613, 'readers')
# (614, 'illuminate')
# (615, 'manuscript')
# (616, 'medieval')
# (617, 'press')
# (618, 'skeptics')
# (619, 'al')
# (620, 'et')
# (621, 'parameswaran')
# (622, 'peer')
# (623, 'loose')
# (624, 'division')
# (625, 'fix')
# (626, 'principle')
# (627, 'bittorrent')
# (628, 'central')
# (629, 'cohen')
# (630, 'list')
# (631, 'locally')
# (632, 'members')
# (633, 'nearby')
# (634, 'inspect')
# (635, 'member')
# (636, 'name')
# (637, 'indefinitely')
# (638, 'lookup')
# (639, 'repeat')
# (640, 'activity')
# (641, 'excel')
# (642, 'tedious')
# (643, 'case')
# (644, 'copyright')
# (645, 'hit')
# (646, 'infringement')
# (647, 'lam')
# (648, 'macedonia')
# (649, 'napster')
# (650, 'shut')
# (651, 'tan')
# (652, 'legal')
# (653, 'domain')
# (654, 'families')
# (655, 'fan')
# (656, 'movies')
# (657, 'package')
# (658, 'public')
# (659, 'inherently')
# (660, 'considerably')
# (661, 'future')
# (662, 'interactions')
# (663, 'answer')
# (664, 'basically')
# (665, 'broad')
# (666, 'category')
# (667, 'millions')
# (668, 'contain')
# (669, 'picture')
# (670, 'text')
# (671, 'smell')
# (672, 'addict')
# (673, 'instant')
# (674, 'salt')
# (675, 'teenager')
# (676, 'derive')
# (677, 'facility')
# (678, 'real')
# (679, 'talk')
# (680, 'type')
# (681, 'unix')
# (682, 'audiences')
# (683, 'circle')
# (684, 'friends')
# (685, 'multi')
# (686, 'tweet')
# (687, 'twitter')
# (688, 'will')
# (689, 'station')
# (690, 'attend')
# (691, 'cheap')
# (692, 'experience')
# (693, 'rich')
# (694, 'telelearning')
# (695, 'bed')
# (696, 'class')
# (697, 'inconvenience')
# (698, 'long')
# (699, 'prove')
# (700, 'challenge')
# (701, 'city')
# (702, 'geographically')
# (703, 'hugely')
# (704, 'live')
# (705, 'middle')
# (706, 'declare')
# (707, 'drive')
# (708, 'flow')
# (709, 'relationships')
# (710, 'facebook')
# (711, 'profile')
# (712, 'introductions')
# (713, 'news')
# (714, 'loosely')
# (715, 'collaborative')
# (716, 'community')
# (717, 'edit')
# (718, 'site')
# (719, 'wiki')
# (720, 'encyclopedia')
# (721, 'famous')
# (722, 'wikipedia')
# (723, 'wikis')
# (724, 'broadest')
# (725, 'configurations')
# (726, 'interactive')
# (727, 'viewpoints')
# (728, 'consult')
# (729, 'support')
# (730, 'account')
# (731, 'investments')
# (732, 'manage')
# (733, 'pay')
# (734, 'surely')
# (735, 'ure')
# (736, 'flea')
# (737, 'foresee')
# (738, 'auction')
# (739, 'hand')
# (740, 'buyers')
# (741, 'consumers')
# (742, 'follow')
# (743, 'sellers')
# (744, 'unlike')
# (745, 'acquire')
# (746, 'cute')
# (747, 'little')
# (748, 'pronounce')
# (749, 'tag')
# (750, 'car')
# (751, 'manufacturer')
# (752, 'supplier')
# (753, 'tire')
# (754, 'fourth')
# (755, 'begin')
# (756, 'huge')
# (757, 'mechanisms')
# (758, 'rival')
# (759, 'stride')
# (760, 'dvd')
# (761, 'mp')
# (762, 'quality')
# (763, 'songs')
# (764, 'cable')
# (765, 'iptv')
# (766, 'reach')
# (767, 'transmissions')
# (768, 'tv')
# (769, 'episodes')
# (770, 'favorite')
# (771, 'media')
# (772, 'stream')
# (773, 'tune')
# (774, 'watch')
# (775, 'display')
# (776, 'move')
# (777, 'naturally')
# (778, 'speakers')
# (779, 'country')
# (780, 'movie')
# (781, 'search')
# (782, 'soon')
# (783, 'alternative')
# (784, 'bide')
# (785, 'direction')
# (786, 'duncan')
# (787, 'film')
# (788, 'macbeth')
# (789, 'murder')
# (790, 'occasionally')
# (791, 'prompt')
# (792, 'scenarios')
# (793, 'story')
# (794, 'audience')
# (795, 'choose')
# (796, 'contestants')
# (797, 'participate')
# (798, 'quiz')
# (799, 'play')
# (800, 'dungeon')
# (801, 'flight')
# (802, 'hide')
# (803, 'multiperson')
# (804, 'seek')
# (805, 'simulation')
# (806, 'oppose')
# (807, 'players')
# (808, 'shoot')
# (809, 'simulators')
# (810, 'team')
# (811, 'try')
# (812, 'dimensional')
# (813, 'graphics')
# (814, 'persistent')
# (815, 'reality')
# (816, 'worlds')
# (817, 'compute')
# (818, 'everyday')
# (819, 'life')
# (820, 'mark')
# (821, 'ubiquitous')
# (822, 'vision')
# (823, 'weiser')
# (824, 'consumption')
# (825, 'door')
# (826, 'energy')
# (827, 'fold')
# (828, 'sensors')
# (829, 'smart')
# (830, 'urity')
# (831, 'window')
# (832, 'electricity')
# (833, 'gas')
# (834, 'meter')
# (835, 'department')
# (836, 'detectors')
# (837, 'noise')
# (838, 'smoke')
# (839, 'drop')
# (840, 'measurement')
# (841, 'increasingly')
# (842, 'cameras')
# (843, 'capability')
# (844, 'view')
# (845, 'editors')
# (846, 'photographers')
# (847, 'wirelessly')
# (848, 'plug')
# (849, 'power')
# (850, 'televisions')
# (851, 'object')
# (852, 'surprise')
# (853, 'think')
# (854, 'environmental')
# (855, 'feedback')
# (856, 'lather')
# (857, 'shower')
# (858, 'visual')
# (859, 'frequency')
# (860, 'identification')
# (861, 'rfid')
# (862, 'passive')
# (863, 'affix')
# (864, 'battery')
# (865, 'card')
# (866, 'chip')
# (867, 'credit')
# (868, 'items')
# (869, 'passports')
# (870, 'pet')
# (871, 'depend')
# (872, 'distance')
# (873, 'kind')
# (874, 'locate')
# (875, 'barcodes')
# (876, 'commercialize')
# (877, 'originally')
# (878, 'cents')
# (879, 'succeed')
# (880, 'decline')
# (881, 'offer')
# (882, 'price')
# (883, 'itu')
# (884, 'things')
# (885, 'turn')
# (886, 'fastest')
# (887, 'handheld')
# (888, 'laptop')
# (889, 'segment')
# (890, 'overtake')
# (891, 'simply')
# (892, 'land')
# (893, 'sea')
# (894, 'airplanes')
# (895, 'boat')
# (896, 'cars')
# (897, 'lot')
# (898, 'blanket')
# (899, 'cellular')
# (900, 'coverage')
# (901, 'familiar')
# (902, 'hotspots')
# (903, 'standard')
# (904, 'airports')
# (905, 'cafes')
# (906, 'hotels')
# (907, 'patchwork')
# (908, 'plan')
# (909, 'school')
# (910, 'spring')
# (911, 'train')
# (912, 'hotspot')
# (913, 'modem')
# (914, 'contact')
# (915, 'delivery')
# (916, 'fleet')
# (917, 'keep')
# (918, 'repairpersons')
# (919, 'taxis')
# (920, 'truck')
# (921, 'vehicles')
# (922, 'businessmen')
# (923, 'cities')
# (924, 'drivers')
# (925, 'taxi')
# (926, 'driver')
# (927, 'destination')
# (928, 'dispatcher')
# (929, 'pickup')
# (930, 'beep')
# (931, 'sound')
# (932, 'military')
# (933, 'count')
# (934, 'earth')
# (935, 'fight')
# (936, 'good')
# (937, 'infrastructure')
# (938, 'notice')
# (939, 'war')
# (940, 'identical')
# (941, 'relate')
# (942, 'notebook')
# (943, 'hotel')
# (944, 'jack')
# (945, 'mobility')
# (946, 'traveler')
# (947, 'typical')
# (948, 'unwire')
# (949, 'yes')
# (950, 'combinations')
# (951, 'conversely')
# (952, 'convenient')
# (953, 'install')
# (954, 'lack')
# (955, 'suitable')
# (956, 'electronics')
# (957, 'instal')
# (958, 'unpack')
# (959, 'ducts')
# (960, 'solution')
# (961, 'workmen')
# (962, 'finally')
# (963, 'true')
# (964, 'walk')
# (965, 'busy')
# (966, 'clerk')
# (967, 'park')
# (968, 'rental')
# (969, 'return')
# (970, 'device')
# (971, 'scan')
# (972, 'spot')
# (973, 'texting')
# (974, 'tremendously')
# (975, 'deliver')
# (976, 'subscriber')
# (977, 'ago')
# (978, 'immense')
# (979, 'maker')
# (980, 'predict')
# (981, 'tediously')
# (982, 'teenagers')
# (983, 'carrier')
# (984, 'cent')
# (985, 'charge')
# (986, 'fraction')
# (987, 'profitable')
# (988, 'relay')
# (989, 'tiny')
# (990, 'accelerate')
# (991, 'arrive')
# (992, 'await')
# (993, 'convergence')
# (994, 'aspects')
# (995, 'combine')
# (996, 'iphone')
# (997, 'fast')
# (998, 'advance')
# (999, 'automatically')
# (1000, 'best')
# (1001, 'option')
# (1002, 'switch')
# (1003, 'stay')
# (1004, 'edition')
# (1005, 'magazine')
# (1006, 'newly')
# (1007, 'purchase')
# (1008, 'roam')
# (1009, 'today')
# (1010, 'cue')
# (1011, 'frame')
# (1012, 'fresh')
# (1013, 'image')
# (1014, 'equip')
# (1015, 'global')
# (1016, 'gps')
# (1017, 'intentionally')
# (1018, 'position')
# (1019, 'receivers')
# (1020, 'candidate')
# (1021, 'directions')
# (1022, 'map')
# (1023, 'bookstore')
# (1024, 'chinese')
# (1025, 'forecast')
# (1026, 'restaurant')
# (1027, 'weather')
# (1028, 'annotate')
# (1029, 'annotation')
# (1030, 'geo')
# (1031, 'senn')
# (1032, 'authorize')
# (1033, 'cash')
# (1034, 'food')
# (1035, 'payments')
# (1036, 'ticket')
# (1037, 'vend')
# (1038, 'field')
# (1039, 'near')
# (1040, 'nfc')
# (1041, 'payment')
# (1042, 'reader')
# (1043, 'smartcard')
# (1044, 'force')
# (1045, 'hard')
# (1046, 'makers')
# (1047, 'operators')
# (1048, 'phenomenon')
# (1049, 'pie')
# (1050, 'piece')
# (1051, 'fee')
# (1052, 'percent')
# (1053, 'scheme')
# (1054, 'backfire')
# (1055, 'barcode')
# (1056, 'check')
# (1057, 'competitors')
# (1058, 'detail')
# (1059, 'item')
# (1060, 'accustom')
# (1061, 'thing')
# (1062, 'howl')
# (1063, 'accept')
# (1064, 'normal')
# (1065, 'operator')
# (1066, 'register')
# (1067, 'tack')
# (1068, 'wave')
# (1069, 'doubt')
# (1070, 'shrink')
# (1071, 'possibilities')
# (1072, 'quick')
# (1073, 'nod')
# (1074, 'sensor')
# (1075, 'state')
# (1076, 'board')
# (1077, 'diagnostic')
# (1078, 'fuel')
# (1079, 'hull')
# (1080, 'speed')
# (1081, 'upload')
# (1082, 'vibration')
# (1083, 'congest')
# (1084, 'guzzler')
# (1085, 'potholes')
# (1086, 'road')
# (1087, 'roads')
# (1088, 'stretch')
# (1089, 'trip')
# (1090, 'behavior')
# (1091, 'observe')
# (1092, 'revolutionize')
# (1093, 'wealth')
# (1094, 'animal')
# (1095, 'juang')
# (1096, 'migration')
# (1097, 'track')
# (1098, 'zebras')
# (1099, 'cube')
# (1100, 'edge')
# (1101, 'mm')
# (1102, 'pack')
# (1103, 'researchers')
# (1104, 'warneke')
# (1105, 'bird')
# (1106, 'ints')
# (1107, 'rodents')
# (1108, 'mundane')
# (1109, 'significant')
# (1110, 'debit')
# (1111, 'verification')
# (1112, 'easily')
# (1113, 'bounce')
# (1114, 'enforcement')
# (1115, 'expiration')
# (1116, 'expire')
# (1117, 'presence')
# (1118, 'signal')
# (1119, 'estimate')
# (1120, 'governments')
# (1121, 'additional')
# (1122, 'billion')
# (1123, 'harte')
# (1124, 'promise')
# (1125, 'wearable')
# (1126, 'appearance')
# (1127, 'comic')
# (1128, 'dick')
# (1129, 'mental')
# (1130, 'space')
# (1131, 'strip')
# (1132, 'tracy')
# (1133, 'implant')
# (1134, 'insulin')
# (1135, 'pacemakers')
# (1136, 'pump')
# (1137, 'doctor')
# (1138, 'reconfigure')
# (1139, 'test')
# (1140, 'average')
# (1141, 'hack')
# (1142, 'halperin')
# (1143, 'inure')
# (1144, 'lead')
# (1145, 'nasty')
# (1146, 'pc')
# (1147, 'problems')
# (1148, 'citizens')
# (1149, 'ordinary')
# (1150, 'bad')
# (1151, 'ethical')
# (1152, 'freedom')
# (1153, 'political')
# (1154, 'unsolved')
# (1155, 'briefly')
# (1156, 'study')
# (1157, 'thorough')
# (1158, 'host')
# (1159, 'mind')
# (1160, 'arise')
# (1161, 'garden')
# (1162, 'restrict')
# (1163, 'actually')
# (1164, 'care')
# (1165, 'politics')
# (1166, 'religion')
# (1167, 'sex')
# (1168, 'trouble')
# (1169, 'deeply')
# (1170, 'offensive')
# (1171, 'post')
# (1172, 'publicly')
# (1173, 'correct')
# (1174, 'politically')
# (1175, 'worse')
# (1176, 'clip')
# (1177, 'color')
# (1178, 'furthermore')
# (1179, 'limit')
# (1180, 'opinions')
# (1181, 'photograph')
# (1182, 'resolution')
# (1183, 'certain')
# (1184, 'feel')
# (1185, 'material')
# (1186, 'attack')
# (1187, 'particular')
# (1188, 'pornography')
# (1189, 'religions')
# (1190, 'verbal')
# (1191, 'censor')
# (1192, 'unacceptable')
# (1193, 'conflict')
# (1194, 'laws')
# (1195, 'debate')
# (1196, 'rag')
# (1197, 'claim')
# (1198, 'past')
# (1199, 'sue')
# (1200, 'inevitable')
# (1201, 'police')
# (1202, 'block')
# (1203, 'learn')
# (1204, 'slight')
# (1205, 'amount')
# (1206, 'cut')
# (1207, 'traffic')
# (1208, 'differently')
# (1209, 'treat')
# (1210, 'player')
# (1211, 'poor')
# (1212, 'argue')
# (1213, 'bits')
# (1214, 'opponents')
# (1215, 'practice')
# (1216, 'argument')
# (1217, 'differentiate')
# (1218, 'neutrality')
# (1219, 'source')
# (1220, 'wu')
# (1221, 'safe')
# (1222, 'party')
# (1223, 'tussle')
# (1224, 'action')
# (1225, 'holders')
# (1226, 'instance')
# (1227, 'pirate')
# (1228, 'threaten')
# (1229, 'automate')
# (1230, 'infringe')
# (1231, 'suspect')
# (1232, 'warn')
# (1233, 'dmca')
# (1234, 'millennium')
# (1235, 'takedown')
# (1236, 'unite')
# (1237, 'arm')
# (1238, 'catch')
# (1239, 'reliably')
# (1240, 'culprit')
# (1241, 'mistake')
# (1242, 'piatek')
# (1243, 'snoop')
# (1244, 'employer')
# (1245, 'right')
# (1246, 'versus')
# (1247, 'employers')
# (1248, 'hours')
# (1249, 'possibly')
# (1250, 'agree')
# (1251, 'citizen')
# (1252, 'fbi')
# (1253, 'incoming')
# (1254, 'nuggets')
# (1255, 'outgo')
# (1256, 'providers')
# (1257, 'bellovin')
# (1258, 'blaze')
# (1259, 'carnivore')
# (1260, 'dcs')
# (1261, 'early')
# (1262, 'innocent')
# (1263, 'publicity')
# (1264, 'rename')
# (1265, 'sobel')
# (1266, 'zacks')
# (1267, 'activities')
# (1268, 'find')
# (1269, 'hope')
# (1270, 'illegal')
# (1271, 'spy')
# (1272, 'amendment')
# (1273, 'unfortunately')
# (1274, 'constitution')
# (1275, 'ignore')
# (1276, 'prohibit')
# (1277, 'warrant')
# (1278, 'monopoly')
# (1279, 'privacy')
# (1280, 'bite')
# (1281, 'tor')
# (1282, 'berghel')
# (1283, 'browsers')
# (1284, 'confidential')
# (1285, 'cookies')
# (1286, 'cyberspace')
# (1287, 'leak')
# (1288, 'directly')
# (1289, 'advertisements')
# (1290, 'gmail')
# (1291, 'google')
# (1292, 'beresford')
# (1293, 'stajano')
# (1294, 'twist')
# (1295, 'day')
# (1296, 'movements')
# (1297, 'frequent')
# (1298, 'medical')
# (1299, 'nightclub')
# (1300, 'visit')
# (1301, 'anonymous')
# (1302, 'increase')
# (1303, 'potential')
# (1304, 'desirable')
# (1305, 'situations')
# (1306, 'blow')
# (1307, 'fear')
# (1308, 'habit')
# (1309, 'officer')
# (1310, 'professors')
# (1311, 'reprisals')
# (1312, 'soldier')
# (1313, 'students')
# (1314, 'superiors')
# (1315, 'whistle')
# (1316, 'accusations')
# (1317, 'accuse')
# (1318, 'accuser')
# (1319, 'confront')
# (1320, 'court')
# (1321, 'democracies')
# (1322, 'evidence')
# (1323, 'permit')
# (1324, 'specifically')
# (1325, 'consider')
# (1326, 'downright')
# (1327, 'ill')
# (1328, 'mislead')
# (1329, 'wrong')
# (1330, 'advice')
# (1331, 'chest')
# (1332, 'dropout')
# (1333, 'nobel')
# (1334, 'pain')
# (1335, 'pluck')
# (1336, 'prize')
# (1337, 'winner')
# (1338, 'frequently')
# (1339, 'unwanted')
# (1340, 'address')
# (1341, 'cheaply')
# (1342, 'junk')
# (1343, 'marketers')
# (1344, 'spam')
# (1345, 'spammers')
# (1346, 'flood')
# (1347, 'degrees')
# (1348, 'discard')
# (1349, 'filter')
# (1350, 'fortunately')
# (1351, 'greater')
# (1352, 'lesser')
# (1353, 'success')
# (1354, 'criminal')
# (1355, 'intend')
# (1356, 'active')
# (1357, 'execute')
# (1358, 'macros')
# (1359, 'receiver')
# (1360, 'viruses')
# (1361, 'botnet')
# (1362, 'compromise')
# (1363, 'passwords')
# (1364, 'pool')
# (1365, 'steal')
# (1366, 'masquerade')
# (1367, 'originate')
# (1368, 'phishing')
# (1369, 'reveal')
# (1370, 'sensitive')
# (1371, 'trick')
# (1372, 'trustworthy')
# (1373, 'identity')
# (1374, 'obtain')
# (1375, 'problem')
# (1376, 'theft')
# (1377, 'thieve')
# (1378, 'victim')
# (1379, 'difficult')
# (1380, 'impersonate')
# (1381, 'ahn')
# (1382, 'captchas')
# (1383, 'development')
# (1384, 'distort')
# (1385, 'recognition')
# (1386, 'solve')
# (1387, 'task')
# (1388, 'von')
# (1389, 'entity')
# (1390, 'judge')
# (1391, 'question')
# (1392, 'respond')
# (1393, 'turing')
# (1394, 'variation')
# (1395, 'seriously')
# (1396, 'authenticate')
# (1397, 'commit')
# (1398, 'encrypt')
# (1399, 'harder')
# (1400, 'mischief')
# (1401, 'establish')
# (1402, 'feature')
# (1403, 'put')
# (1404, 'vendors')
# (1405, 'addition')
# (1406, 'bug')
# (1407, 'buggy')
# (1408, 'code')
# (1409, 'inevitably')
# (1410, 'occur')
# (1411, 'quarter')
# (1412, 'sell')
# (1413, 'tough')
# (1414, 'bankrupt')
# (1415, 'defective')
# (1416, 'entire')
# (1417, 'nice')
# (1418, 'refund')
# (1419, 'raise')
# (1420, 'gamble')
# (1421, 'blackjack')
# (1422, 'dealers')
# (1423, 'roulette')
# (1424, 'simulate')
# (1425, 'slot')
# (1426, 'wheel')
# (1427, 'casino')
# (1428, 'england')
# (1429, 'grasp')
# (1430, 'owners')
# (1431, 'gambler')
# (1432, 'attention')
# (1433, 'dessert')
# (1434, 'spinach')
# (1435, 'dimension')
# (1436, 'fit')
# (1437, 'scale')
# (1438, 'stand')
# (1439, 'taxonomy')
# (1440, 'transmission')
# (1441, 'broadcast')
# (1442, 'speak')
# (1443, 'pair')
# (1444, 'contexts')
# (1445, 'intermediate')
# (1446, 'packets')
# (1447, 'lengths')
# (1448, 'multiple')
# (1449, 'rout')
# (1450, 'exactly')
# (1451, 'sender')
# (1452, 'unicasting')
# (1453, 'channel')
# (1454, 'receive')
# (1455, 'packet')
# (1456, 'recipient')
# (1457, 'specify')
# (1458, 'region')
# (1459, 'transmit')
# (1460, 'analogy')
# (1461, 'shout')
# (1462, 'watson')
# (1463, 'destinations')
# (1464, 'possibility')
# (1465, 'special')
# (1466, 'mode')
# (1467, 'operation')
# (1468, 'multicasting')
# (1469, 'subset')
# (1470, 'classify')
# (1471, 'criterion')
# (1472, 'classification')
# (1473, 'metric')
# (1474, 'technologies')
# (1475, 'range')
# (1476, 'divide')
# (1477, 'metropolitan')
# (1478, 'internetwork')
# (1479, 'certainly')
# (1480, 'burleigh')
# (1481, 'internetworks')
# (1482, 'interplanetary')
# (1483, 'campus')
# (1484, 'continent')
# (1485, 'interprocessor')
# (1486, 'planet')
# (1487, 'processors')
# (1488, 'concern')
# (1489, 'brief')
# (1490, 'tions')
# (1491, 'pan')
# (1492, 'peripherals')
# (1493, 'attach')
# (1494, 'keyboard')
# (1495, 'mouse')
# (1496, 'cod')
# (1497, 'hole')
# (1498, 'technician')
# (1499, 'bluetooth')
# (1500, 'components')
# (1501, 'ease')
# (1502, 'master')
# (1503, 'slave')
# (1504, 'normally')
# (1505, 'unit')
# (1506, 'frequencies')
# (1507, 'settings')
# (1508, 'cord')
# (1509, 'headset')
# (1510, 'configuration')
# (1511, 'merely')
# (1512, 'aid')
# (1513, 'completely')
# (1514, 'pacemaker')
# (1515, 'discuss')
# (1516, 'smartcards')
# (1517, 'lan')
# (1518, 'factory')
# (1519, 'own')
# (1520, 'privately')
# (1521, 'lans')
# (1522, 'enterprise')
# (1523, 'cafeterias')
# (1524, 'older')
# (1525, 'antenna')
# (1526, 'ceiling')
# (1527, 'ap')
# (1528, 'router')
# (1529, 'kid')
# (1530, 'close')
# (1531, 'popularly')
# (1532, 'wifi')
# (1533, 'port')
# (1534, 'rest')
# (1535, 'mbps')
# (1536, 'adhere')
# (1537, 'gbps')
# (1538, 'gigabits')
# (1539, 'measure')
# (1540, 'megabits')
# (1541, 'tradition')
# (1542, 'optical')
# (1543, 'bound')
# (1544, 'worst')
# (1545, 'protocols')
# (1546, 'delay')
# (1547, 'errors')
# (1548, 'low')
# (1549, 'microonds')
# (1550, 'nanoonds')
# (1551, 'typically')
# (1552, 'newer')
# (1553, 'exceed')
# (1554, 'performance')
# (1555, 'topology')
# (1556, 'protocol')
# (1557, 'determine')
# (1558, 'designers')
# (1559, 'loop')
# (1560, 'luckily')
# (1561, 'paths')
# (1562, 'safely')
# (1563, 'sort')
# (1564, 'logical')
# (1565, 'useful')
# (1566, 'layout')
# (1567, 'match')
# (1568, 'structure')
# (1569, 'departments')
# (1570, 'engineer')
# (1571, 'finance')
# (1572, 'logically')
# (1573, 'vlan')
# (1574, 'wing')
# (1575, 'green')
# (1576, 'red')
# (1577, 'forward')
# (1578, 'cover')
# (1579, 'topologies')
# (1580, 'vlans')
# (1581, 'linear')
# (1582, 'original')
# (1583, 'version')
# (1584, 'arbitration')
# (1585, 'mechanism')
# (1586, 'resolve')
# (1587, 'successfully')
# (1588, 'algorithm')
# (1589, 'idle')
# (1590, 'collide')
# (1591, 'random')
# (1592, 'allocate')
# (1593, 'clarity')
# (1594, 'classic')
# (1595, 'dynamic')
# (1596, 'static')
# (1597, 'allocation')
# (1598, 'discrete')
# (1599, 'intervals')
# (1600, 'robin')
# (1601, 'round')
# (1602, 'capacity')
# (1603, 'dynamically')
# (1604, 'waste')
# (1605, 'decentralize')
# (1606, 'methods')
# (1607, 'method')
# (1608, 'accord')
# (1609, 'internal')
# (1610, 'prioritize')
# (1611, 'approach')
# (1612, 'chaos')
# (1613, 'algorithms')
# (1614, 'spend')
# (1615, 'accessible')
# (1616, 'appliance')
# (1617, 'capable')
# (1618, 'concepts')
# (1619, 'visionary')
# (1620, 'appliances')
# (1621, 'dvds')
# (1622, 'thermostat')
# (1623, 'tvs')
# (1624, 'utility')
# (1625, 'adjust')
# (1626, 'daylight')
# (1627, 'children')
# (1628, 'parent')
# (1629, 'properties')
# (1630, 'routers')
# (1631, 'elevator')
# (1632, 'helpline')
# (1633, 'foolproof')
# (1634, 'conditioners')
# (1635, 'knob')
# (1636, 'manuals')
# (1637, 'ter')
# (1638, 'refrigerator')
# (1639, 'tolerant')
# (1640, 'geek')
# (1641, 'hire')
# (1642, 'essential')
# (1643, 'premium')
# (1644, 'temperature')
# (1645, 'extra')
# (1646, 'expand')
# (1647, 'gradually')
# (1648, 'format')
# (1649, 'firewire')
# (1650, 'interfaces')
# (1651, 'retract')
# (1652, 'usb')
# (1653, 'interface')
# (1654, 'month')
# (1655, 'oops')
# (1656, 'skittish')
# (1657, 'remain')
# (1658, 'stable')
# (1659, 'standards')
# (1660, 'fifth')
# (1661, 'reliability')
# (1662, 'burglar')
# (1663, 'disarm')
# (1664, 'lose')
# (1665, 'plunder')
# (1666, 'virus')
# (1667, 'favor')
# (1668, 'retrofit')
# (1669, 'neighbor')
# (1670, 'overjoy')
# (1671, 'piggyback')
# (1672, 'encryption')
# (1673, 'inexperienced')
# (1674, 'appeal')
# (1675, 'reuse')
# (1676, 'electric')
# (1677, 'outlets')
# (1678, 'difficulty')
# (1679, 'band')
# (1680, 'opportunities')
# (1681, 'dependable')
# (1682, 'nontechnical')
# (1683, 'man')
# (1684, 'examples')
# (1685, 'earlier')
# (1686, 'reception')
# (1687, 'hill')
# (1688, 'pip')
# (1689, 'subscribers')
# (1690, 'ad')
# (1691, 'hoc')
# (1692, 'contract')
# (1693, 'jump')
# (1694, 'specialize')
# (1695, 'inception')
# (1696, 'late')
# (1697, 'attract')
# (1698, 'realize')
# (1699, 'spectrum')
# (1700, 'unused')
# (1701, 'morph')
# (1702, 'approximation')
# (1703, 'feed')
# (1704, 'headend')
# (1705, 'subsequent')
# (1706, 'highspeed')
# (1707, 'standardize')
# (1708, 'wimax')
# (1709, 'span')
# (1710, 'wan')
# (1711, 'branch')
# (1712, 'discussion')
# (1713, 'head')
# (1714, 'junction')
# (1715, 'subnet')
# (1716, 'listener')
# (1717, 'distinct')
# (1718, 'elements')
# (1719, 'lease')
# (1720, 'element')
# (1721, 'commonly')
# (1722, 'doubter')
# (1723, 'rhyme')
# (1724, 'rooter')
# (1725, 'exercise')
# (1726, 'pronunciation')
# (1727, 'perceive')
# (1728, 'comment')
# (1729, 'aware')
# (1730, 'conjunction')
# (1731, 'stick')
# (1732, 'describe')
# (1733, 'similar')
# (1734, 'brisbane')
# (1735, 'melbourne')
# (1736, 'perth')
# (1737, 'australia')
# (1738, 'boundaries')
# (1739, 'clearer')
# (1740, 'provider')
# (1741, 'greatly')
# (1742, 'overall')
# (1743, 'separation')
# (1744, 'simplify')
# (1745, 'kinds')
# (1746, 'sonet')
# (1747, 'astute')
# (1748, 'definition')
# (1749, 'composite')
# (1750, 'tion')
# (1751, 'final')
# (1752, 'varieties')
# (1753, 'dedicate')
# (1754, 'underlie')
# (1755, 'advantage')
# (1756, 'flexible')
# (1757, 'usual')
# (1758, 'virtualization')
# (1759, 'vpn')
# (1760, 'disadvantage')
# (1761, 'mileage')
# (1762, 'vary')
# (1763, 'disappoint')
# (1764, 'isp')
# (1765, 'preview')
# (1766, 'ters')
# (1767, 'indirectly')
# (1768, 'wish')
# (1769, 'decision')
# (1770, 'path')
# (1771, 'heavy')
# (1772, 'grind')
# (1773, 'orbit')
# (1774, 'fellow')
# (1775, 'output')
# (1776, 'upward')
# (1777, 'property')
# (1778, 'generations')
# (1779, 'horizon')
# (1780, 'analog')
# (1781, 'generation')
# (1782, 'kilometers')
# (1783, 'tens')
# (1784, 'backbone')
# (1785, 'rat')
# (1786, 'desire')
# (1787, 'fulfillment')
# (1788, 'incompatible')
# (1789, 'capitalize')
# (1790, 'generic')
# (1791, 'specific')
# (1792, 'confuse')
# (1793, 'subnets')
# (1794, 'businesses')
# (1795, 'combination')
# (1796, 'arrangements')
# (1797, 'distinguish')
# (1798, 'constitute')
# (1799, 'agreement')
# (1800, 'terminology')
# (1801, 'rule')
# (1802, 'thumb')
# (1803, 'deeper')
# (1804, 'gateway')
# (1805, 'necessary')
# (1806, 'translation')
# (1807, 'gateways')
# (1808, 'hierarchy')
# (1809, 'hierarchies')
# (1810, 'higher')
# (1811, 'lower')
# (1812, 'tie')
# (1813, 'level')
# (1814, 'unable')
# (1815, 'afterthought')
# (1816, 'strategy')
# (1817, 'keystone')
# (1818, 'repeatedly')
# (1819, 'complexity')
# (1820, 'stack')
# (1821, 'differ')
# (1822, 'function')
# (1823, 'purpose')
# (1824, 'shield')
# (1825, 'encapsulation')
# (1826, 'orient')
# (1827, 'variously')
# (1828, 'fundamental')
# (1829, 'collectively')
# (1830, 'conventions')
# (1831, 'conversation')
# (1832, 'introduce')
# (1833, 'woman')
# (1834, 'american')
# (1835, 'ball')
# (1836, 'european')
# (1837, 'formal')
# (1838, 'kiss')
# (1839, 'lawyer')
# (1840, 'princess')
# (1841, 'shake')
# (1842, 'violate')
# (1843, 'comprise')
# (1844, 'correspond')
# (1845, 'entities')
# (1846, 'be')
# (1847, 'transfer')
# (1848, 'lowest')
# (1849, 'pass')
# (1850, 'adjacent')
# (1851, 'define')
# (1852, 'operations')
# (1853, 'primitive')
# (1854, 'upper')
# (1855, 'clean')
# (1856, 'considerations')
# (1857, 'understand')
# (1858, 'clearcut')
# (1859, 'implementation')
# (1860, 'minimize')
# (1861, 'upstairs')
# (1862, 'implementations')
# (1863, 'architecture')
# (1864, 'appropriate')
# (1865, 'correctly')
# (1866, 'implementer')
# (1867, 'obey')
# (1868, 'specification')
# (1869, 'architectures')
# (1870, 'principal')
# (1871, 'multilayer')
# (1872, 'english')
# (1873, 'french')
# (1874, 'philosophers')
# (1875, 'urdu')
# (1876, 'engage')
# (1877, 'language')
# (1878, 'retary')
# (1879, 'translator')
# (1880, 'affection')
# (1881, 'convey')
# (1882, 'cuniculus')
# (1883, 'oryctolagus')
# (1884, 'philosopher')
# (1885, 'rabbit')
# (1886, 'convert')
# (1887, 'dutch')
# (1888, 'ik')
# (1889, 'konijnen')
# (1890, 'leuk')
# (1891, 'neutral')
# (1892, 'translators')
# (1893, 'vind')
# (1894, 'choice')
# (1895, 'translate')
# (1896, 'finnish')
# (1897, 'disturb')
# (1898, 'inform')
# (1899, 'retaries')
# (1900, 'similarly')
# (1901, 'header')
# (1902, 'identify')
# (1903, 'preserve')
# (1904, 'sequence')
# (1905, 'impose')
# (1906, 'nearly')
# (1907, 'break')
# (1908, 'aime')
# (1909, 'bien')
# (1910, 'fax')
# (1911, 'lapins')
# (1912, 'les')
# (1913, 'prepending')
# (1914, 'units')
# (1915, 'separately')
# (1916, 'split')
# (1917, 'trailer')
# (1918, 'headers')
# (1919, 'conceptually')
# (1920, 'horizontal')
# (1921, 'getfrom')
# (1922, 'otherside')
# (1923, 'procedures')
# (1924, 'sendtootherside')
# (1925, 'abstraction')
# (1926, 'crucial')
# (1927, 'complete')
# (1928, 'manageable')
# (1929, 'unmanageable')
# (1930, 'firmware')
# (1931, 'complex')
# (1932, 'unreliable')
# (1933, 'chance')
# (1934, 'damage')
# (1935, 'electrical')
# (1936, 'flaw')
# (1937, 'fluke')
# (1938, 'invert')
# (1939, 'detection')
# (1940, 'error')
# (1941, 'incorrectly')
# (1942, 'retransmit')
# (1943, 'correction')
# (1944, 'incorrect')
# (1945, 'recover')
# (1946, 'redundant')
# (1947, 'protect')
# (1948, 'germany')
# (1949, 'suppose')
# (1950, 'london')
# (1951, 'paris')
# (1952, 'rome')
# (1953, 'topic')
# (1954, 'evolution')
# (1955, 'emerge')
# (1956, 'see')
# (1957, 'strategies')
# (1958, 'senders')
# (1959, 'respectively')
# (1960, 'aspect')
# (1961, 'limitations')
# (1962, 'solutions')
# (1963, 'maximum')
# (1964, 'disassemble')
# (1965, 'reassemble')
# (1966, 'internetworking')
# (1967, 'jam')
# (1968, 'shortage')
# (1969, 'citywide')
# (1970, 'neighborhood')
# (1971, 'scalable')
# (1972, 'interfere')
# (1973, 'bandwidth')
# (1974, 'shortterm')
# (1975, 'multiplexing')
# (1976, 'statistical')
# (1977, 'statistics')
# (1978, 'apply')
# (1979, 'slow')
# (1980, 'swamp')
# (1981, 'oversubscribed')
# (1982, 'congestion')
# (1983, 'overload')
# (1984, 'matter')
# (1985, 'timeliness')
# (1986, 'throughput')
# (1987, 'compete')
# (1988, 'reconcile')
# (1989, 'defend')
# (1990, 'major')
# (1991, 'threats')
# (1992, 'eavesdrop')
# (1993, 'confidentiality')
# (1994, 'threat')
# (1995, 'authentication')
# (1996, 'fake')
# (1997, 'alter')
# (1998, 'integrity')
# (1999, 'surreptitious')
# (2000, 'connectionless')
# (2001, 'cryptography')
# (2002, 'shall')
# (2003, 'dial')
# (2004, 'hang')
# (2005, 'pick')
# (2006, 'release')
# (2007, 'tube')
# (2008, 'conduct')
# (2009, 'negotiation')
# (2010, 'parameters')
# (2011, 'counterproposal')
# (2012, 'proposal')
# (2013, 'reject')
# (2014, 'associate')
# (2015, 'circuit')
# (2016, 'date')
# (2017, 'postal')
# (2018, 'node')
# (2019, 'onward')
# (2020, 'characterize')
# (2021, 'reliable')
# (2022, 'acknowledge')
# (2023, 'receipt')
# (2024, 'sure')
# (2025, 'acknowledgement')
# (2026, 'overhead')
# (2027, 'undesirable')
# (2028, 'situation')
# (2029, 'owner')
# (2030, 'prefer')
# (2031, 'scramble')
# (2032, 'byte')
# (2033, 'minor')
# (2034, 'variations')
# (2035, 'variant')
# (2036, 'bytes')
# (2037, 'phototypesetter')
# (2038, 'transit')
# (2039, 'digitize')
# (2040, 'disruptive')
# (2041, 'irritate')
# (2042, 'jerk')
# (2043, 'pixels')
# (2044, 'stop')
# (2045, 'recipients')
# (2046, 'spammer')
# (2047, 'tear')
# (2048, 'arrival')
# (2049, 'guarantee')
# (2050, 'probability')
# (2051, 'datagram')
# (2052, 'telegram')
# (2053, 'despite')
# (2054, 'absolutely')
# (2055, 'query')
# (2056, 'retrieve')
# (2057, 'inherent')
# (2058, 'multimedia')
# (2059, 'coexist')
# (2060, 'formally')
# (2061, 'primitives')
# (2062, 'kernel')
# (2063, 'trap')
# (2064, 'nature')
# (2065, 'minimal')
# (2066, 'berkeley')
# (2067, 'socket')
# (2068, 'disconnect')
# (2069, 'terminate')
# (2070, 'environment')
# (2071, 'interaction')
# (2072, 'datagrams')
# (2073, 'sketch')
# (2074, 'indicate')
# (2075, 'prepare')
# (2076, 'parameter')
# (2077, 'suspend')
# (2078, 'unblock')
# (2079, 'manager')
# (2080, 'ring')
# (2081, 'execution')
# (2082, 'initial')
# (2083, 'nutshell')
# (2084, 'moment')
# (2085, 'perfect')
# (2086, 'face')
# (2087, 'megabyte')
# (2088, 'miss')
# (2089, 'inadequate')
# (2090, 'overcome')
# (2091, 'suffice')
# (2092, 'relationship')
# (2093, 'emphasize')
# (2094, 'behalf')
# (2095, 'govern')
# (2096, 'definitions')
# (2097, 'decouple')
# (2098, 'designer')
# (2099, 'languages')
# (2100, 'pointer')
# (2101, 'blunder')
# (2102, 'reference')
# (2103, 'osi')
# (2104, 'tcp')
# (2105, 'valid')
# (2106, 'opposite')
# (2107, 'failures')
# (2108, 'successes')
# (2109, 'minus')
# (2110, 'develop')
# (2111, 'international')
# (2112, 'iso')
# (2113, 'standardization')
# (2114, 'zimmermann')
# (2115, 'revise')
# (2116, 'interconnection')
# (2117, 'open')
# (2118, 'seven')
# (2119, 'principles')
# (2120, 'eye')
# (2121, 'internationally')
# (2122, 'apdu')
# (2123, 'boundary')
# (2124, 'ppdu')
# (2125, 'presentation')
# (2126, 'session')
# (2127, 'spdu')
# (2128, 'tpdu')
# (2129, 'necessity')
# (2130, 'throw')
# (2131, 'unwieldy')
# (2132, 'exact')
# (2133, 'publish')
# (2134, 'forget')
# (2135, 'raw')
# (2136, 'connector')
# (2137, 'last')
# (2138, 'pin')
# (2139, 'represent')
# (2140, 'side')
# (2141, 'largely')
# (2142, 'transform')
# (2143, 'undetected')
# (2144, 'mask')
# (2145, 'accomplish')
# (2146, 'input')
# (2147, 'sequentially')
# (2148, 'thousand')
# (2149, 'confirm')
# (2150, 'drown')
# (2151, 'transmitter')
# (2152, 'regulation')
# (2153, 'sublayer')
# (2154, 'avoid')
# (2155, 'fail')
# (2156, 'rarely')
# (2157, 'table')
# (2158, 'login')
# (2159, 'terminal')
# (2160, 'anew')
# (2161, 'load')
# (2162, 'reflect')
# (2163, 'bottleneck')
# (2164, 'adapt')
# (2165, 'responsibility')
# (2166, 'jitter')
# (2167, 'heterogeneous')
# (2168, 'nonexistent')
# (2169, 'basic')
# (2170, 'ensure')
# (2171, 'efficiently')
# (2172, 'isolate')
# (2173, 'ultimately')
# (2174, 'achieve')
# (2175, 'aside')
# (2176, 'rate')
# (2177, 'immediate')
# (2178, 'ultimate')
# (2179, 'sessions')
# (2180, 'checkpointing')
# (2181, 'crash')
# (2182, 'critical')
# (2183, 'dialog')
# (2184, 'event')
# (2185, 'recovery')
# (2186, 'synchronization')
# (2187, 'token')
# (2188, 'semantics')
# (2189, 'syntax')
# (2190, 'encode')
# (2191, 'representations')
# (2192, 'http')
# (2193, 'hypertext')
# (2194, 'browser')
# (2195, 'arpanet')
# (2196, 'grandparent')
# (2197, 'successor')
# (2198, 'dod')
# (2199, 'research')
# (2200, 'sponsor')
# (2201, 'defense')
# (2202, 'eventually')
# (2203, 'installations')
# (2204, 'universities')
# (2205, 'interworking')
# (2206, 'goals')
# (2207, 'seamless')
# (2208, 'primary')
# (2209, 'braden')
# (2210, 'cerf')
# (2211, 'kahn')
# (2212, 'refine')
# (2213, 'clark')
# (2214, 'philosophy')
# (2215, 'conversations')
# (2216, 'loss')
# (2217, 'precious')
# (2218, 'soviet')
# (2219, 'survive')
# (2220, 'union')
# (2221, 'worry')
# (2222, 'intact')
# (2223, 'divergent')
# (2224, 'envision')
# (2225, 'requirements')
# (2226, 'speech')
# (2227, 'serial')
# (2228, 'linchpin')
# (2229, 'independently')
# (2230, 'inject')
# (2231, 'potentially')
# (2232, 'rearrange')
# (2233, 'snail')
# (2234, 'luck')
# (2235, 'mailbox')
# (2236, 'transparent')
# (2237, 'envelope')
# (2238, 'companion')
# (2239, 'icmp')
# (2240, 'official')
# (2241, 'clearly')
# (2242, 'effective')
# (2243, 'udp')
# (2244, 'accurate')
# (2245, 'relation')
# (2246, 'ftp')
# (2247, 'smtp')
# (2248, 'telnet')
# (2249, 'dsl')
# (2250, 'dns')
# (2251, 'rtp')
# (2252, 'fetch')
# (2253, 'exceptionally')
# (2254, 'strength')
# (2255, 'cake')
# (2256, 'eat')
# (2257, 'hybrid')
# (2258, 'scientists')
# (2259, 'finite')
# (2260, 'length')
# (2261, 'abstractions')
# (2262, 'strengthen')
# (2263, 'portion')
# (2264, 'concentrate')
# (2265, 'retain')
# (2266, 'comparison')
# (2267, 'functionality')
# (2268, 'similarities')
# (2269, 'piscitello')
# (2270, 'contribution')
# (2271, 'explicit')
# (2272, 'affect')
# (2273, 'ideas')
# (2274, 'nicely')
# (2275, 'consequence')
# (2276, 'relatively')
# (2277, 'transparently')
# (2278, 'devise')
# (2279, 'invent')
# (2280, 'bias')
# (2281, 'downside')
# (2282, 'graft')
# (2283, 'paper')
# (2284, 'specifications')
# (2285, 'sublayers')
# (2286, 'committee')
# (2287, 'description')
# (2288, 'reverse')
# (2289, 'perfectly')
# (2290, 'non')
# (2291, 'philosophical')
# (2292, 'inter')
# (2293, 'critique')
# (2294, 'criticism')
# (2295, 'direct')
# (2296, 'criticisms')
# (2297, 'afterward')
# (2298, 'experts')
# (2299, 'david')
# (2300, 'apocalypse')
# (2301, 'elephants')
# (2302, 'theory')
# (2303, 'surround')
# (2304, 'burst')
# (2305, 'discussions')
# (2306, 'corporations')
# (2307, 'dollar')
# (2308, 'investment')
# (2309, 'subside')
# (2310, 'trough')
# (2311, 'poorly')
# (2312, 'effectively')
# (2313, 'crush')
# (2314, 'hurry')
# (2315, 'interval')
# (2316, 'academic')
# (2317, 'cautiously')
# (2318, 'overfull')
# (2319, 'extraordinarily')
# (2320, 'occupy')
# (2321, 'pile')
# (2322, 'inefficient')
# (2323, 'cite')
# (2324, 'cross')
# (2325, 'mobster')
# (2326, 'mockapetris')
# (2327, 'paul')
# (2328, 'pose')
# (2329, 'riddle')
# (2330, 'rise')
# (2331, 'reappear')
# (2332, 'saltzer')
# (2333, 'highest')
# (2334, 'unnecessary')
# (2335, 'enormous')
# (2336, 'burn')
# (2337, 'improve')
# (2338, 'improvements')
# (2339, 'downward')
# (2340, 'spiral')
# (2341, 'academia')
# (2342, 'apple')
# (2343, 'motherhood')
# (2344, 'parenthood')
# (2345, 'creature')
# (2346, 'ministries')
# (2347, 'belief')
# (2348, 'bunch')
# (2349, 'bureaucrats')
# (2350, 'inferior')
# (2351, 'partly')
# (2352, 'programmers')
# (2353, 'shove')
# (2354, 'technically')
# (2355, 'throats')
# (2356, 'trench')
# (2357, 'ada')
# (2358, 'announce')
# (2359, 'light')
# (2360, 'pl')
# (2361, 'carefully')
# (2362, 'guide')
# (2363, 'suit')
# (2364, 'sloppy')
# (2365, 'characteristics')
# (2366, 'delimit')
# (2367, 'proper')
# (2368, 'couple')
# (2369, 'graduate')
# (2370, 'entrench')
# (2371, 'embarrassment')
# (2372, 'character')
# (2373, 'teletype')
# (2374, 'mice')
# (2375, 'vast')
# (2376, 'unusual')
# (2377, 'john')
# (2378, 'naughton')
# (2379, 'recommend')
# (2380, 'ibid')
# (2381, 'rare')
# (2382, 'historian')
# (2383, 'countless')
# (2384, 'maufer')
# (2385, 'cold')
# (2386, 'height')
# (2387, 'command')
# (2388, 'nuclear')
# (2389, 'vulnerable')
# (2390, 'glean')
# (2391, 'black')
# (2392, 'dot')
# (2393, 'national')
# (2394, 'redundancy')
# (2395, 'toll')
# (2396, 'destruction')
# (2397, 'fragment')
# (2398, 'islands')
# (2399, 'vulnerability')
# (2400, 'baran')
# (2401, 'propose')
# (2402, 'award')
# (2403, 'rand')
# (2404, 'fault')
# (2405, 'distortion')
# (2406, 'officials')
# (2407, 'pentagon')
# (2408, 'prototype')
# (2409, 'dismiss')
# (2410, 'richest')
# (2411, 'whippersnapper')
# (2412, 'kill')
# (2413, 'andcontrol')
# (2414, 'beat')
# (2415, 'october')
# (2416, 'artificial')
# (2417, 'sputnik')
# (2418, 'appal')
# (2419, 'army')
# (2420, 'asleep')
# (2421, 'budget')
# (2422, 'eisenhower')
# (2423, 'navy')
# (2424, 'squabble')
# (2425, 'arpa')
# (2426, 'project')
# (2427, 'laboratories')
# (2428, 'grant')
# (2429, 'mission')
# (2430, 'larry')
# (2431, 'roberts')
# (2432, 'suggest')
# (2433, 'wesley')
# (2434, 'gatlinburg')
# (2435, 'sigops')
# (2436, 'skepticism')
# (2437, 'somewhat')
# (2438, 'symposium')
# (2439, 'tennessee')
# (2440, 'vague')
# (2441, 'davies')
# (2442, 'donald')
# (2443, 'laboratory')
# (2444, 'demonstrate')
# (2445, 'npl')
# (2446, 'imps')
# (2447, 'kbps')
# (2448, 'minicomputers')
# (2449, 'imp')
# (2450, 'destroy')
# (2451, 'rerouted')
# (2452, 'entirety')
# (2453, 'storeand')
# (2454, 'tender')
# (2455, 'bid')
# (2456, 'bbn')
# (2457, 'cambridge')
# (2458, 'december')
# (2459, 'evaluate')
# (2460, 'massachusetts')
# (2461, 'proposals')
# (2462, 'core')
# (2463, 'ddp')
# (2464, 'honeywell')
# (2465, 'memory')
# (2466, 'modify')
# (2467, 'specially')
# (2468, 'disk')
# (2469, 'afford')
# (2470, 'opinion')
# (2471, 'convene')
# (2472, 'snowbird')
# (2473, 'summer')
# (2474, 'utah')
# (2475, 'assign')
# (2476, 'expert')
# (2477, 'grand')
# (2478, 'astound')
# (2479, 'experimental')
# (2480, 'sri')
# (2481, 'ucla')
# (2482, 'ucsb')
# (2483, 'months')
# (2484, 'kleinrock')
# (2485, 'len')
# (2486, 'pioneer')
# (2487, 'aberdeen')
# (2488, 'ames')
# (2489, 'belvoir')
# (2490, 'burroughs')
# (2491, 'carn')
# (2492, 'cca')
# (2493, 'cmu')
# (2494, 'etac')
# (2495, 'fnwc')
# (2496, 'gwc')
# (2497, 'harvard')
# (2498, 'illinois')
# (2499, 'lbl')
# (2500, 'linc')
# (2501, 'lincoln')
# (2502, 'mcclellan')
# (2503, 'mit')
# (2504, 'mitre')
# (2505, 'nbs')
# (2506, 'ncar')
# (2507, 'noaa')
# (2508, 'parc')
# (2509, 'radc')
# (2510, 'saac')
# (2511, 'sdc')
# (2512, 'stan')
# (2513, 'stanford')
# (2514, 'tinker')
# (2515, 'tip')
# (2516, 'ucsd')
# (2517, 'usc')
# (2518, 'september')
# (2519, 'fledgling')
# (2520, 'fund')
# (2521, 'california')
# (2522, 'coast')
# (2523, 'college')
# (2524, 'demonstration')
# (2525, 'east')
# (2526, 'ship')
# (2527, 'researcher')
# (2528, 'experiment')
# (2529, 'culminate')
# (2530, 'observation')
# (2531, 'hook')
# (2532, 'adoption')
# (2533, 'dec')
# (2534, 'encourage')
# (2535, 'hp')
# (2536, 'platforms')
# (2537, 'rewrite')
# (2538, 'sockets')
# (2539, 'upcoming')
# (2540, 'bsd')
# (2541, 'vax')
# (2542, 'adopt')
# (2543, 'utilities')
# (2544, 'domains')
# (2545, 'expensive')
# (2546, 'generalize')
# (2547, 'nsf')
# (2548, 'nsfnet')
# (2549, 'collaborate')
# (2550, 'foundation')
# (2551, 'impact')
# (2552, 'csnet')
# (2553, 'labs')
# (2554, 'boulder')
# (2555, 'champaign')
# (2556, 'concrete')
# (2557, 'diego')
# (2558, 'ithaca')
# (2559, 'pittsburgh')
# (2560, 'princeton')
# (2561, 'san')
# (2562, 'supercomputer')
# (2563, 'brother')
# (2564, 'fuzzball')
# (2565, 'lsi')
# (2566, 'microcomputer')
# (2567, 'fuzzballs')
# (2568, 'museums')
# (2569, 'regional')
# (2570, 'supercomputers')
# (2571, 'carnegie')
# (2572, 'mellon')
# (2573, 'midlevel')
# (2574, 'instantaneous')
# (2575, 'consortium')
# (2576, 'merit')
# (2577, 'michigan')
# (2578, 'mci')
# (2579, 'optic')
# (2580, 'worldcom')
# (2581, 'rts')
# (2582, 'overwhelm')
# (2583, 'upgrade')
# (2584, 'forever')
# (2585, 'charter')
# (2586, 'commercial')
# (2587, 'forbid')
# (2588, 'ans')
# (2589, 'nonprofit')
# (2590, 'america')
# (2591, 'nap')
# (2592, 'transition')
# (2593, 'ameritech')
# (2594, 'chicago')
# (2595, 'francisco')
# (2596, 'mfs')
# (2597, 'pacbell')
# (2598, 'washington')
# (2599, 'jersey')
# (2600, 'pennsauken')
# (2601, 'sprint')
# (2602, 'carriers')
# (2603, 'commercially')
# (2604, 'competitive')
# (2605, 'default')
# (2606, 'criticize')
# (2607, 'federal')
# (2608, 'innovative')
# (2609, 'pattern')
# (2610, 'regions')
# (2611, 'ebone')
# (2612, 'europanet')
# (2613, 'europe')
# (2614, 'emergence')
# (2615, 'explode')
# (2616, 'www')
# (2617, 'million')
# (2618, 'cern')
# (2619, 'guess')
# (2620, 'radically')
# (2621, 'academics')
# (2622, 'dominate')
# (2623, 'newsgroups')
# (2624, 'everyman')
# (2625, 'shutter')
# (2626, 'microblogging')
# (2627, 'regularity')
# (2628, 'explosively')
# (2629, 'overview')
# (2630, 'complicate')
# (2631, 'continuous')
# (2632, 'isps')
# (2633, 'telcos')
# (2634, 'upheavals')
# (2635, 'assumption')
# (2636, 'triple')
# (2637, 'tomorrow')
# (2638, 'attribute')
# (2639, 'cmts')
# (2640, 'dialup')
# (2641, 'dslam')
# (2642, 'ftth')
# (2643, 'ixp')
# (2644, 'pop')
# (2645, 'tier')
# (2646, 'unhindered')
# (2647, 'multiplexer')
# (2648, 'demodulator')
# (2649, 'modulator')
# (2650, 'termination')
# (2651, 'megabit')
# (2652, 'narrow')
# (2653, 'broadband')
# (2654, 'broader')
# (2655, 'leg')
# (2656, 'mile')
# (2657, 'residences')
# (2658, 'nearest')
# (2659, 'north')
# (2660, 'explore')
# (2661, 'shortly')
# (2662, 'enter')
# (2663, 'scope')
# (2664, 'destine')
# (2665, 'ixps')
# (2666, 'draw')
# (2667, 'vertically')
# (2668, 'facilities')
# (2669, 'amsterdam')
# (2670, 'largest')
# (2671, 'alternatively')
# (2672, 'cooperate')
# (2673, 'metz')
# (2674, 'paradoxes')
# (2675, 'choices')
# (2676, 'route')
# (2677, 'shortest')
# (2678, 'handful')
# (2679, 'yahoo')
# (2680, 'farm')
# (2681, 'fill')
# (2682, 'humans')
# (2683, 'rack')
# (2684, 'backbones')
# (2685, 'colocation')
# (2686, 'rent')
# (2687, 'virtualized')
# (2688, 'tour')
# (2689, 'undermine')
# (2690, 'firewalls')
# (2691, 'difficulties')
# (2692, 'intranets')
# (2693, 'notebooks')
# (2694, 'premise')
# (2695, 'love')
# (2696, 'successful')
# (2697, 'perspective')
# (2698, 'population')
# (2699, 'continuously')
# (2700, 'amps')
# (2701, 'deploy')
# (2702, 'firstgeneration')
# (2703, 'gsm')
# (2704, 'jargon')
# (2705, 'body')
# (2706, 'stationary')
# (2707, 'vehicle')
# (2708, 'umts')
# (2709, 'universal')
# (2710, 'wcdma')
# (2711, 'wideband')
# (2712, 'downlink')
# (2713, 'uplink')
# (2714, 'antennas')
# (2715, 'scarce')
# (2716, 'license')
# (2717, 'submit')
# (2718, 'total')
# (2719, 'uk')
# ...
# (7938, 'photocopy')
# (7939, 'tuesday')
# (7940, 'handwrite')
# (7941, 'letterhead')
# (7942, 'tamper')
# (7943, 'foil')
# (7944, 'wiretapping')
# (7945, 'drill')
# (7946, 'decrypt')
# (7947, 'oblivious')
# (7948, 'quasi')
# (7949, 'incompetent')
# (7950, 'lax')
# (7951, 'socalled')
# (7952, 'criminals')
# (7953, 'inattention')
# (7954, 'opener')
# (7955, 'ross')
# (7956, 'thoughts')
# (7957, 'biometrics')
# (7958, 'injection')
# (7959, 'trojan')
# (7960, 'worm')
# (7961, 'kaufman')
# (7962, 'stinson')
# (7963, 'burnett')
# (7964, 'paine')
# (7965, 'linguistic')
# (7966, 'glorious')
# (7967, 'antitank')
# (7968, 'chay')
# (7969, 'dagahi')
# (7970, 'indians')
# (7971, 'nail')
# (7972, 'navajo')
# (7973, 'tortoise')
# (7974, 'tsaidi')
# (7975, 'weapon')
# (7976, 'tonal')
# (7977, 'bottle')
# (7978, 'earful')
# (7979, 'gurgle')
# (7980, 'intersperse')
# (7981, 'marines')
# (7982, 'monk')
# (7983, 'tibetan')
# (7984, 'bravery')
# (7985, 'extraordinary')
# (7986, 'talkers')
# (7987, 'victories')
# (7988, 'corps')
# (7989, 'diarists')
# (7990, 'diplomatic')
# (7991, 'elite')
# (7992, 'specialists')
# (7993, 'retrain')
# (7994, 'ciphertext')
# (7995, 'intruder')
# (7996, 'messenger')
# (7997, 'cryptanalysis')
# (7998, 'cryptology')
# (7999, 'dk')
# (8000, 'subscript')
# (8001, 'cryptanalyst')
# (8002, 'encryptions')
# (8003, 'auguste')
# (8004, 'cryptographer')
# (8005, 'flemish')
# (8006, 'kerckhoff')
# (8007, 'nonrecy')
# (8008, 'obscurity')
# (8009, 'cryptologists')
# (8010, 'publicize')
# (8011, 'cryptograms')
# (8012, 'abcdefghijkl')
# (8013, 'novices')
# (8014, 'trivially')
# (8015, 'withstand')
# (8016, 'opponent')
# (8017, 'unbreakable')
# (8018, 'transposition')
# (8019, 'caesar')
# (8020, 'julius')
# (8021, 'dwwdfn')
# (8022, 'alphabet')
# (8023, 'pompey')
# (8024, 'qwe')
# (8025, 'vwx')
# (8026, 'monoalphabetic')
# (8027, 'qzzqea')
# (8028, 'digrams')
# (8029, 'ing')
# (8030, 'ion')
# (8031, 'trigrams')
# (8032, 'txe')
# (8033, 'thyt')
# (8034, 'azw')
# (8035, 'trigram')
# (8036, 'consonants')
# (8037, 'vowels')
# (8038, 'phrase')
# (8039, 'probable')
# (8040, 'bgaqj')
# (8041, 'bnybn')
# (8042, 'btjds')
# (8043, 'btswx')
# (8044, 'byctc')
# (8045, 'cqvuj')
# (8046, 'ctbmn')
# (8047, 'ctqtz')
# (8048, 'dsksu')
# (8049, 'gstjc')
# (8050, 'jdsts')
# (8051, 'jquus')
# (8052, 'jsntk')
# (8053, 'jubxj')
# (8054, 'mnqjs')
# (8055, 'qjsgs')
# (8056, 'qjsw')
# (8057, 'qxbns')
# (8058, 'tjqzz')
# (8059, 'tlctz')
# (8060, 'vlnsx')
# (8061, 'vszju')
# (8062, 'zbgyq')
# (8063, 'occurrences')
# (8064, 'columnar')
# (8065, 'megabuck')
# (8066, 'milliondollars')
# (8067, 'il')
# (8068, 'ir')
# (8069, 'la')
# (8070, 'mo')
# (8071, 'ia')
# (8072, 'io')
# (8073, 'md')
# (8074, 'digram')
# (8075, 'milloin')
# (8076, 'twelfth')
# (8077, 'immune')
# (8078, 'plaintexts')
# (8079, 'elvis')
# (8080, 'memorize')
# (8081, 'personally')
# (8082, 'quantum')
# (8083, 'provably')
# (8084, 'bb')
# (8085, 'bennet')
# (8086, 'brassard')
# (8087, 'principals')
# (8088, 'banker')
# (8089, 'rivest')
# (8090, 'ron')
# (8091, 'cryptographers')
# (8092, 'intrepid')
# (8093, 'photons')
# (8094, 'polarize')
# (8095, 'sunglasses')
# (8096, 'wearers')
# (8097, 'orientation')
# (8098, 'rectilinear')
# (8099, 'plural')
# (8100, 'diagonal')
# (8101, 'crystal')
# (8102, 'polarization')
# (8103, 'photon')
# (8104, 'qubits')
# (8105, 'onetime')
# (8106, 'concatenation')
# (8107, 'qubit')
# (8108, 'forwarderror')
# (8109, 'clone')
# (8110, 'mullins')
# (8111, 'couch')
# (8112, 'intruders')
# (8113, 'punish')
# (8114, 'franchise')
# (8115, 'playgrounds')
# (8116, 'sandboxes')
# (8117, 'swing')
# (8118, 'exemployee')
# (8119, 'cryptanalysts')
# (8120, 'dearly')
# (8121, 'sofa')
# (8122, 'tuber')
# (8123, 'encipher')
# (8124, 'involuted')
# (8125, 'substitutions')
# (8126, 'transpositions')
# (8127, 'permutation')
# (8128, 'permute')
# (8129, 'octal')
# (8130, 'decoders')
# (8131, 'gate')
# (8132, 'subnanoond')
# (8133, 'transpose')
# (8134, 'sboxes')
# (8135, 'stag')
# (8136, 'iterations')
# (8137, 'subblocks')
# (8138, 'unclassified')
# (8139, 'ki')
# (8140, 'iteration')
# (8141, 'ri')
# (8142, 'whiten')
# (8143, 'lucifer')
# (8144, 'nsa')
# (8145, 'mathematicians')
# (8146, 'supposedly')
# (8147, 'comfortable')
# (8148, 'discreetly')
# (8149, 'diffie')
# (8150, 'hellman')
# (8151, 'kumar')
# (8152, 'tuchman')
# (8153, 'ede')
# (8154, 'eee')
# (8155, 'paranoid')
# (8156, 'paranoia')
# (8157, 'keenly')
# (8158, 'bake')
# (8159, 'finalists')
# (8160, 'potshots')
# (8161, 'daemen')
# (8162, 'joan')
# (8163, 'rijmen')
# (8164, 'vincent')
# (8165, 'doll')
# (8166, 'rhine')
# (8167, 'fips')
# (8168, 'belgian')
# (8169, 'openness')
# (8170, 'microprocessors')
# (8171, 'doubtful')
# (8172, 'candlelight')
# (8173, 'provable')
# (8174, 'permutations')
# (8175, 'ferguson')
# (8176, 'init')
# (8177, 'ncols')
# (8178, 'nrows')
# (8179, 'rk')
# (8180, 'roundkey')
# (8181, 'structs')
# (8182, 'rotation')
# (8183, 'attraction')
# (8184, 'diffuse')
# (8185, 'gf')
# (8186, 'appendix')
# (8187, 'reversible')
# (8188, 'abcdefgh')
# (8189, 'subvert')
# (8190, 'ecb')
# (8191, 'leslie')
# (8192, 'kim')
# (8193, 'rectify')
# (8194, 'unfair')
# (8195, 'christmas')
# (8196, 'merrier')
# (8197, 'iv')
# (8198, 'nonsense')
# (8199, 'ensue')
# (8200, 'investigation')
# (8201, 'vacate')
# (8202, 'accidentally')
# (8203, 'keystream')
# (8204, 'proposition')
# (8205, 'keystreams')
# (8206, 'ciphertexts')
# (8207, 'liability')
# (8208, 'blame')
# (8209, 'twofish')
# (8210, 'biham')
# (8211, 'bruce')
# (8212, 'knudsen')
# (8213, 'rc')
# (8214, 'ronald')
# (8215, 'schneier')
# (8216, 'serpent')
# (8217, 'shamir')
# (8218, 'probabilistic')
# (8219, 'matsui')
# (8220, 'alligator')
# (8221, 'cryptosystems')
# (8222, 'cryptosystem')
# (8223, 'vault')
# (8224, 'feasibly')
# (8225, 'hearts')
# (8226, 'publickey')
# (8227, 'ea')
# (8228, 'da')
# (8229, 'eb')
# (8230, 'adleman')
# (8231, 'discoverers')
# (8232, 'prim')
# (8233, 'inverses')
# (8234, 'euclid')
# (8235, 'brute')
# (8236, 'descendants')
# (8237, 'numeric')
# (8238, 'knapsack')
# (8239, 'merkle')
# (8240, 'ralph')
# (8241, 'adi')
# (8242, 'dare')
# (8243, 'leonard')
# (8244, 'logarithms')
# (8245, 'el')
# (8246, 'gamal')
# (8247, 'schnorr')
# (8248, 'elliptic')
# (8249, 'menezes')
# (8250, 'vanstone')
# (8251, 'authenticity')
# (8252, 'breakthroughs')
# (8253, 'handwritten')
# (8254, 'unforgeable')
# (8255, 'repudiate')
# (8256, 'dishonest')
# (8257, 'ra')
# (8258, 'kbb')
# (8259, 'accountants')
# (8260, 'confidence')
# (8261, 'unreasonable')
# (8262, 'subsequently')
# (8263, 'jail')
# (8264, 'perjury')
# (8265, 'disclose')
# (8266, 'burglarize')
# (8267, 'allegedly')
# (8268, 'legally')
# (8269, 'liable')
# (8270, 'dss')
# (8271, 'uproar')
# (8272, 'allege')
# (8273, 'genuine')
# (8274, 'bless')
# (8275, 'nonret')
# (8276, 'sb')
# (8277, 'pseudo')
# (8278, 'temp')
# (8279, 'soup')
# (8280, 'suspicion')
# (8281, 'sotirov')
# (8282, 'knell')
# (8283, 'crypto')
# (8284, 'swindle')
# (8285, 'yuval')
# (8286, 'birthdays')
# (8287, 'tenure')
# (8288, 'chairperson')
# (8289, 'dean')
# (8290, 'marilyn')
# (8291, 'ellen')
# (8292, 'frank')
# (8293, 'romantically')
# (8294, 'wilson')
# (8295, 'creative')
# (8296, 'insights')
# (8297, 'talent')
# (8298, 'admire')
# (8299, 'educator')
# (8300, 'rave')
# (8301, 'instructor')
# (8302, 'gift')
# (8303, 'raiser')
# (8304, 'urge')
# (8305, 'embarrass')
# (8306, 'imprudent')
# (8307, 'ridicule')
# (8308, 'insignificant')
# (8309, 'conscience')
# (8310, 'faith')
# (8311, 'tonight')
# (8312, 'approval')
# (8313, 'affair')
# (8314, 'confess')
# (8315, 'furious')
# (8316, 'ridiculous')
# (8317, 'trillion')
# (8318, 'weeks')
# (8319, 'wiser')
# (8320, 'reencrypting')
# (8321, 'kdc')
# (8322, 'halt')
# (8323, 'certify')
# (8324, 'certification')
# (8325, 'avenue')
# (8326, 'ffa')
# (8327, 'holder')
# (8328, 'loan')
# (8329, 'moneybank')
# (8330, 'ou')
# (8331, 'cas')
# (8332, 'asn')
# (8333, 'verbose')
# (8334, 'baum')
# (8335, 'issuer')
# (8336, 'infrastructures')
# (8337, 'leakage')
# (8338, 'risky')
# (8339, 'pki')
# (8340, 'toplevel')
# (8341, 'ae')
# (8342, 'daughter')
# (8343, 'legitimacy')
# (8344, 'son')
# (8345, 'sleazy')
# (8346, 'shady')
# (8347, 'revocation')
# (8348, 'drunken')
# (8349, 'offenses')
# (8350, 'revoke')
# (8351, 'grantor')
# (8352, 'crl')
# (8353, 'crls')
# (8354, 'conceivably')
# (8355, 'nonpayment')
# (8356, 'reinstate')
# (8357, 'reinstatement')
# (8358, 'revocations')
# (8359, 'carte')
# (8360, 'isakmp')
# (8361, 'ike')
# (8362, 'decapsulates')
# (8363, 'colorado')
# (8364, 'crisis')
# (8365, 'rocky')
# (8366, 'ah')
# (8367, 'antireplay')
# (8368, 'hmac')
# (8369, 'falsify')
# (8370, 'dire')
# (8371, 'breach')
# (8372, 'pests')
# (8373, 'careless')
# (8374, 'import')
# (8375, 'castle')
# (8376, 'moat')
# (8377, 'standby')
# (8378, 'drawbridge')
# (8379, 'demilitarize')
# (8380, 'uncermoniously')
# (8381, 'complaints')
# (8382, 'dmz')
# (8383, 'stateful')
# (8384, 'sophistication')
# (8385, 'blemish')
# (8386, 'insider')
# (8387, 'disgruntle')
# (8388, 'entrance')
# (8389, 'denial')
# (8390, 'do')
# (8391, 'firepower')
# (8392, 'unsuspecting')
# (8393, 'ddos')
# (8394, 'bogus')
# (8395, 'olden')
# (8396, 'wiretap')
# (8397, 'illusion')
# (8398, 'sas')
# (8399, 'lewis')
# (8400, 'sieve')
# (8401, 'afternoon')
# (8402, 'goodies')
# (8403, 'blurt')
# (8404, 'lekkas')
# (8405, 'nichols')
# (8406, 'linklevel')
# (8407, 'fluhrer')
# (8408, 'dialogue')
# (8409, 'eap')
# (8410, 'delve')
# (8411, 'contraction')
# (8412, 'nonces')
# (8413, 'nonce')
# (8414, 'ks')
# (8415, 'mic')
# (8416, 'mics')
# (8417, 'nonceap')
# (8418, 'noncec')
# (8419, 'tkip')
# (8420, 'ccmp')
# (8421, 'trudies')
# (8422, 'agricultural')
# (8423, 'barn')
# (8424, 'passkeys')
# (8425, 'hardcoded')
# (8426, 'weaken')
# (8427, 'jakobsson')
# (8428, 'wetzel')
# (8429, 'biryukov')
# (8430, 'amaze')
# (8431, 'perennial')
# (8432, 'imposter')
# (8433, 'scott')
# (8434, 'affirmative')
# (8435, 'kab')
# (8436, 'challenger')
# (8437, 'rb')
# (8438, 'teller')
# (8439, 'rt')
# (8440, 'calmly')
# (8441, 'hesitation')
# (8442, 'resistant')
# (8443, 'rub')
# (8444, 'hmacs')
# (8445, 'strangers')
# (8446, 'openly')
# (8447, 'gx')
# (8448, 'gy')
# (8449, 'xth')
# (8450, 'gxy')
# (8451, 'behold')
# (8452, 'lo')
# (8453, 'massively')
# (8454, 'deceive')
# (8455, 'gxz')
# (8456, 'gyz')
# (8457, 'gz')
# (8458, 'brigade')
# (8459, 'vaguely')
# (8460, 'stranger')
# (8461, 'grapes')
# (8462, 'sour')
# (8463, 'multiway')
# (8464, 'needham')
# (8465, 'schroeder')
# (8466, 'kt')
# (8467, 'denning')
# (8468, 'sacco')
# (8469, 'journal')
# (8470, 'otway')
# (8471, 'rees')
# (8472, 'kerberos')
# (8473, 'hades')
# (8474, 'multiheaded')
# (8475, 'undesirables')
# (8476, 'workstation')
# (8477, 'yu')
# (8478, 'neuman')
# (8479, 'ts')
# (8480, 'tgs')
# (8481, 'bearer')
# (8482, 'ktgs')
# (8483, 'carol')
# (8484, 'kc')
# (8485, 'realms')
# (8486, 'realm')
# (8487, 'camper')
# (8488, 'fabricate')
# (8489, 'pgp')
# (8490, 'brainchild')
# (8491, 'advocate')
# (8492, 'motto')
# (8493, 'outlaw')
# (8494, 'taint')
# (8495, 'embroil')
# (8496, 'levy')
# (8497, 'munition')
# (8498, 'downloadable')
# (8499, 'jury')
# (8500, 'materiel')
# (8501, 'tank')
# (8502, 'bizarre')
# (8503, 'mildly')
# (8504, 'harass')
# (8505, 'mightier')
# (8506, 'pen')
# (8507, 'sam')
# (8508, 'uncle')
# (8509, 'exportable')
# (8510, 'liberalize')
# (8511, 'circulation')
# (8512, 'gnu')
# (8513, 'distrust')
# (8514, 'dx')
# (8515, 'lempel')
# (8516, 'ziv')
# (8517, 'misnomer')
# (8518, 'unmodified')
# (8519, 'heavyduty')
# (8520, 'alien')
# (8521, 'breakable')
# (8522, 'alienstrength')
# (8523, 'hdr')
# (8524, 'msg')
# (8525, 'sneak')
# (8526, 'correspondents')
# (8527, 'bulletin')
# (8528, 'pem')
# (8529, 'appetizer')
# (8530, 'dirty')
# (8531, 'weekly')
# (8532, 'grim')
# (8533, 'crackers')
# (8534, 'hackers')
# (8535, 'cia')
# (8536, 'blackmail')
# (8537, 'inflict')
# (8538, 'victims')
# (8539, 'emulex')
# (8540, 'quarterly')
# (8541, 'vein')
# (8542, 'resign')
# (8543, 'stockholders')
# (8544, 'perpetrator')
# (8545, 'pinto')
# (8546, 'stuttard')
# (8547, 'merchandise')
# (8548, 'bunny')
# (8549, 'forgery')
# (8550, 'comfort')
# (8551, 'ignorant')
# (8552, 'rrsets')
# (8553, 'rrset')
# (8554, 'untrustworthy')
# (8555, 'naked')
# (8556, 'signer')
# (8557, 'presigning')
# (8558, 'preconfigured')
# (8559, 'ce')
# (8560, 'antispoofing')
# (8561, 'respondent')
# (8562, 'cert')
# (8563, 'safari')
# (8564, 'subprotocols')
# (8565, 'subprotocol')
# (8566, 'premaster')
# (8567, 'cryptanalyzed')
# (8568, 'shaky')
# (8569, 'interoperate')
# (8570, 'cryptanalyze')
# (8571, 'incompatibility')
# (8572, 'javascripts')
# (8573, 'sandbox')
# (8574, 'untrusted')
# (8575, 'xffffffff')
# (8576, 'sandboxed')
# (8577, 'creator')
# (8578, 'authenticode')
# (8579, 'scary')
# (8580, 'shutdown')
# (8581, 'acute')
# (8582, 'garfinkel')
# (8583, 'spafford')
# (8584, 'kitchen')
# (8585, 'standpoint')
# (8586, 'ons')
# (8587, 'animations')
# (8588, 'pdfs')
# (8589, 'frameworks')
# (8590, 'vulnerabilities')
# (8591, 'microkernels')
# (8592, 'agenda')
# (8593, 'policeman')
# (8594, 'cumbersome')
# (8595, 'universe')
# (8596, 'journalists')
# (8597, 'clipper')
# (8598, 'cryptoprocessor')
# (8599, 'escrow')
# (8600, 'denounce')
# (8601, 'furor')
# (8602, 'frontier')
# (8603, 'remailers')
# (8604, 'surveillance')
# (8605, 'anonymously')
# (8606, 'authoritarian')
# (8607, 'dissidents')
# (8608, 'regimes')
# (8609, 'retribution')
# (8610, 'whistleblowers')
# (8611, 'wrongdoing')
# (8612, 'religious')
# (8613, 'alcoholism')
# (8614, 'harassment')
# (8615, 'illness')
# (8616, 'sexual')
# (8617, 'minority')
# (8618, 'newsgroup')
# (8619, 'peruted')
# (8620, 'critics')
# (8621, 'remailer')
# (8622, 'usenet')
# (8623, 'pseudonyms')
# (8624, 'remailed')
# (8625, 'crimes')
# (8626, 'persons')
# (8627, 'bible')
# (8628, 'incidentally')
# (8629, 'stake')
# (8630, 'tyndale')
# (8631, 'outrage')
# (8632, 'cypherpunk')
# (8633, 'confiscate')
# (8634, 'valentine')
# (8635, 'kaashoek')
# (8636, 'mazie')
# (8637, 'res')
# (8638, 'onion')
# (8639, 'peel')
# (8640, 'anonymizer')
# (8641, 'dingledine')
# (8642, 'henceforth')
# (8643, 'paradise')
# (8644, 'ideology')
# (8645, 'regime')
# (8646, 'democratic')
# (8647, 'ethnic')
# (8648, 'hate')
# (8649, 'inappropriate')
# (8650, 'veto')
# (8651, 'breast')
# (8652, 'cancer')
# (8653, 'county')
# (8654, 'loudoun')
# (8655, 'patron')
# (8656, 'virginia')
# (8657, 'livermore')
# (8658, 'memorabilia')
# (8659, 'nazi')
# (8660, 'alcohol')
# (8661, 'arabia')
# (8662, 'iranian')
# (8663, 'liberal')
# (8664, 'pandora')
# (8665, 'saudi')
# (8666, 'gilmore')
# (8667, 'eternity')
# (8668, 'depublished')
# (8669, 'josef')
# (8670, 'stalin')
# (8671, 'uploader')
# (8672, 'jurisdictions')
# (8673, 'resilience')
# (8674, 'repositories')
# (8675, 'freenet')
# (8676, 'pasis')
# (8677, 'wylie')
# (8678, 'publius')
# (8679, 'waldman')
# (8680, 'serjantov')
# (8681, 'helpdesks')
# (8682, 'intangibles')
# (8683, 'restrictive')
# (8684, 'evade')
# (8685, 'steganography')
# (8686, 'closure')
# (8687, 'lawfully')
# (8688, 'repressive')
# (8689, 'greeks')
# (8690, 'herodotus')
# (8691, 'scalp')
# (8692, 'shave')
# (8693, 'acacia')
# (8694, 'unabridged')
# (8695, 'hamlet')
# (8696, 'lear')
# (8697, 'merchant')
# (8698, 'shakespeare')
# (8699, 'venice')
# (8700, 'steganographic')
# (8701, 'covert')
# (8702, 'justice')
# (8703, 'highresolution')
# (8704, 'giveaway')
# (8705, 'lubacz')
# (8706, 'lawful')
# (8707, 'watermarking')
# (8708, 'piva')
# (8709, 'wayner')
# (8710, 'choreographers')
# (8711, 'composers')
# (8712, 'musicians')
# (8713, 'poets')
# (8714, 'gutenberg')
# (8715, 'pg')
# (8716, 'dickens')
# (8717, 'twain')
# (8718, 'forefront')
# (8719, 'contributory')
# (8720, 'tracts')
# (8721, 'brew')
# (8722, 'cabin')
# (8723, 'scanner')
# (8724, 'edward')
# (8725, 'felten')
# (8726, 'usenix')
# (8727, 'lawsuit')
# (8728, 'definitive')
# (8729, 'withdraw')
# (8730, 'motivate')
# (8731, 'craver')
# (8732, 'confrontation')
# (8733, 'topeer')
# (8734, 'infringers')
# (8735, 'doctrine')
# (8736, 'purchasers')
# (8737, 'circumvention')
# (8738, 'showdown')
# (8739, 'tcg')
# (8740, 'tpm')
# (8741, 'lamentable')
# (8742, 'lawmakers')
# (8743, 'litigation')
# (8744, 'meatspace')
# (8745, 'pit')
# (8746, 'struggle')
# (8747, 'sandboxing')
# (8748, 'carroll')
# (8749, 'excerpt')
# (8750, 'bek')
# (8751, 'ed')
# (8752, 'fehfevir')
# (8753, 'idnvy')
# (8754, 'invq')
# (8755, 'irr')
# (8756, 'iuvdtyr')
# (8757, 'je')
# (8758, 'jhrnqvdt')
# (8759, 'jkhjyri')
# (8760, 'jnvy')
# (8761, 'jur')
# (8762, 'jurb')
# (8763, 'jurhri')
# (8764, 'medj')
# (8765, 'mnvjvdt')
# (8766, 'mnyx')
# (8767, 'muvjvdt')
# (8768, 'mvyy')
# (8769, 'ndq')
# (8770, 'nhr')
# (8771, 'nqlndpr')
# (8772, 'nyy')
# (8773, 'oruvdq')
# (8774, 'pezr')
# (8775, 'pyeir')
# (8776, 'qndpr')
# (8777, 'rntrhyb')
# (8778, 'snijrh')
# (8779, 'uem')
# (8780, 'wevd')
# (8781, 'yeoijrhi')
# (8782, 'yvjjyr')
# (8783, 'zb')
# (8784, 'affine')
# (8785, 'aauan')
# (8786, 'aeepb')
# (8787, 'cvlre')
# (8788, 'dltme')
# (8789, 'gorch')
# (8790, 'gsivt')
# (8791, 'iceat')
# (8792, 'iicgo')
# (8793, 'imiha')
# (8794, 'lbolr')
# (8795, 'nntii')
# (8796, 'npmey')
# (8797, 'oofpa')
# (8798, 'otoex')
# (8799, 'rurnn')
# (8800, 'srsoc')
# (8801, 'tpsit')
# (8802, 'ytust')
# (8803, 'decipher')
# (8804, 'disposal')
# (8805, 'lord')
# (8806, 'comma')
# (8807, 'esthetically')
# (8808, 'cipherbreaking')
# (8809, 'astronomy')
# (8810, 'na')
# (8811, 'nb')
# (8812, 'pb')
# (8813, 'diamonds')
# (8814, 'jeweler')
# (8815, 'leap')
# (8816, 'inspections')
# (8817, 'jim')
# (8818, 'mary')
# (8819, 'susceptible')
# (8820, 'stripe')
# (8821, 'merchants')
# (8822, 'pseudonym')
# (8823, 'printouts')

# %%
from gensim.models.coherencemodel import CoherenceModel

coherence_model_lda = CoherenceModel(model=ldamodel, texts=topicwise_words, dictionary=dict_, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Coherence Score:  -2.3450868071558157

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud
import matplotlib.colors as mcolors
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(background_color="white",mask=None, max_words=10,\
                        max_font_size=60,min_font_size=10,prefer_horizontal=0.9,
                        contour_width=3,contour_color='black')

topics = ldamodel.show_topics(formatted=False,num_topics = 100)
# print(topics)
fig, axes = plt.subplots(10,10, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
#     print(topic_words)
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=10))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
import gensim
from gensim import corpora
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

dict_ = corpora.Dictionary(prepro_data)

doc_term_matrix = [dict_.doc2bow(i) for i in prepro_data]
# print(doc_term_matrix)
co_val=[]
Lda = gensim.models.ldamodel.LdaModel
for j in range(100,130):
    print(j)
    ldamodel = Lda(doc_term_matrix, num_topics=j, id2word = dict_, passes=1, random_state=0, eval_every=None)
    for k in ldamodel.print_topics(num_topics=len(prepro_data), num_words=10):
        print(k)
    topicwise_words = []
    topics = ldamodel.show_topics(formatted=False)
#     print(topics)
    for i in range(len(topics)):
        topic_words = dict(topics[i][1])
        word = []
        for ky in topic_words:
            word.append(ky)
        topicwise_words.append(word)

    # print(topicwise_words)
    coherence_model_lda = CoherenceModel(model=ldamodel, texts=topicwise_words, dictionary=dict_, coherence='u_mass')
    coherence_lda = coherence_model_lda.get_coherence()
    co_val.append(coherence_lda)
    print('\nCoherence Score: ', coherence_lda)
print(co_val)
# Out:
# 100
# (0, '0.242*"mean" + 0.216*"reason" + 0.081*"demand" + 0.065*"frequency" + 0.052*"upload" + 0.039*"carefully" + 0.033*"external" + 0.031*"efficiency" + 0.023*"time" + 0.018*"frequencies"')
# (1, '0.424*"new" + 0.070*"purpose" + 0.067*"part" + 0.050*"maintain" + 0.045*"construct" + 0.037*"use" + 0.037*"basis" + 0.025*"consequently" + 0.021*"non" + 0.021*"grant"')
# (2, '0.445*"server" + 0.076*"good" + 0.074*"small" + 0.054*"think" + 0.045*"play" + 0.036*"implement" + 0.035*"pay" + 0.034*"plug" + 0.032*"big" + 0.029*"addition"')
# (3, '0.209*"record" + 0.123*"problems" + 0.089*"help" + 0.088*"apply" + 0.080*"view" + 0.046*"usual" + 0.036*"report" + 0.033*"feedback" + 0.030*"spread" + 0.027*"water"')
# (4, '0.202*"lose" + 0.128*"transmission" + 0.086*"appear" + 0.078*"queue" + 0.058*"transform" + 0.055*"refer" + 0.051*"immediately" + 0.039*"convert" + 0.028*"errors" + 0.017*"data"')
